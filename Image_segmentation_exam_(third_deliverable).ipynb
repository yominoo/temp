# %% [markdown]
# ##Loading and Importing Libraries

# %%
# !pip install tensorflow scikeras matplotlib scikit-learn
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.15.0)
# Requirement already satisfied: scikeras in /usr/local/lib/python3.10/dist-packages (0.12.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.25.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.64.1)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.43.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (1.2.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.0.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (5.4.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2024.7.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow) (2.1.5)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (3.2.2)

# %%
import pandas
import numpy as np
import random
import itertools
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, Conv2DTranspose, MaxPool2D, Concatenate, Input, Lambda, BatchNormalization, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.backend import clear_session
from keras.metrics import MeanIoU
from sklearn.model_selection import train_test_split, learning_curve, GridSearchCV
from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay
from sklearn.utils.class_weight import compute_class_weight

# %% [markdown]
# ##Importing Data

# %%
import urllib.request
import zipfile
# ZIP data URL from GitHub
zip_url = "http://frasca.di.unimi.it/MLDNN/input_data.zip"
# Download the ZIP
zip_path, _ = urllib.request.urlretrieve(zip_url)
# Unzip the folder
target_folder = "temp"
# reading data
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(target_folder)
data_path = f"{target_folder}/input_data.pkl"
#Then use the following lines to read it:
import pickle as pk
with open(data_path, 'rb') as f:
    dd = pk.load(f)

imgs = dd['imgs']
masks = dd['masks']

# %%
imgs.shape, masks.shape
# Out:
# ((1305, 256, 256, 3), (1305, 256, 256, 1))

# %% [markdown]
# Now, I plot some random images with their relative mask to get to understand the context of the task

# %%
def plot_img(idx):
  fig, axs = plt.subplots(1, 2)
  axs[0].imshow(imgs[idx])
  axs[1].imshow(masks[idx])

# %%
idx = random.randint(0, imgs.shape[0]-1)
plot_img(idx)

# %% [markdown]
# So, the images are urban images and the goal is to locate different elements of the urban environment

# %% [markdown]
# ##Data Preprocessing

# %% [markdown]
# Values of the images pixels

# %%
imgs.max(), imgs.min()
# Out:
# (255, 0)

# %% [markdown]
# Values of the masks pixels

# %%
masks.max(), masks.min()
# Out:
# (5, 0)

# %% [markdown]
# Rescale images values in the [0,1] interval

# %%
imgs.dtype
# Out:
# dtype('uint8')

# %%
imgs = imgs.astype('float64')

# %%
imgs /= 255
imgs.max(), imgs.min()
# Out:
# (1.0, 0.0)

# %%
plot_img(random.randint(0,imgs.shape[0]-1))

# %%
img_shape = (imgs.shape[1], imgs.shape[2], imgs.shape[3])

# %%
n_classes = len(np.unique(masks))

# %% [markdown]
# ##Classes balance

# %%
unique, counts = np.unique(masks, return_counts=True)
print(np.asarray((unique, counts)).T)
# Out:
# [[       0 11698953]
#  [       1 45571963]
#  [       2  7985171]
#  [       3  8743823]
#  [       4 11116730]
#  [       5   407840]]

# %% [markdown]
# Class 5 is heavily under represented while class 1 is over represented, so I will adjust class weights in the loss function accordingly

# %%
class_weights = compute_class_weight('balanced', classes=np.unique(masks), y=masks.reshape(-1))
class_weights
# Out:
# array([ 1.21840647,  0.31278179,  1.78506885,  1.63018853,  1.28221878,
#        34.95017654])

# %%
class_weights = {i:weight for i, weight in enumerate(class_weights) }
class_weights
# Out:
# {0: 1.2184064676556954,
#  1: 0.31278178646814053,
#  2: 1.785068848243826,
#  3: 1.6301885342372553,
#  4: 1.282218781961962,
#  5: 34.95017653981954}

# %% [markdown]
# ##Train-Test Splitting

# %%
X_train, X_test, y_train, y_test = train_test_split(imgs, masks, test_size=.2)

# %%
print(X_train.shape, X_test.shape)
print(y_train.shape, y_test.shape)
# Out:
# (1044, 256, 256, 3) (261, 256, 256, 3)
# (1044, 256, 256, 1) (261, 256, 256, 1)

# %% [markdown]
# ##Custom Utility Functions and Classes

# %% [markdown]
# Custom Intersection over Union in order to use it also as training metric

# %%
class CustomMeanIoU(tf.keras.metrics.MeanIoU):
    def __init__(self, num_classes=None, name=None, dtype=None):
        super(CustomMeanIoU, self).__init__(
            num_classes=num_classes, name=name, dtype=dtype
        )

    def update_state(self, y_true, y_pred, sample_weight=None):
        y_pred = tf.math.argmax(y_pred, axis=-1)
        return super().update_state(y_true, y_pred, sample_weight)

# %% [markdown]
# General function to get class weights to train the model given the labels

# %%
def get_class_weights(y):
  class_weights = compute_class_weight('balanced', classes=np.unique(y), y=y.reshape(-1))
  class_weights = {i:weight for i, weight in enumerate(class_weights) }

  return class_weights

# %% [markdown]
# Function to evaluate accuracy and Intersection over Union of a model on a validation set

# %%
def evaluate_model(model, X_tra, y_tra, X_val, y_val, class_weights, batch_size, epochs):
  model.fit(X_tra, y_tra, batch_size=batch_size, epochs=epochs, class_weight=class_weights)
  val_loss, val_acc, val_iou = model.evaluate(X_val, y_val, batch_size=batch_size, verbose=0)

  clear_session()

  return val_loss, val_acc, val_iou

# %% [markdown]
# Function to visualize real imagem real label, predicted label

# %%
def visualize_predictions(X_true, y_true, y_pred, idx):
    fig, axs = plt.subplots(1, 3)
    axs[0].imshow(X_true[idx])
    axs[0].set_title("Image")
    axs[1].imshow(y_true[idx])
    axs[1].set_title("Ground Truth")
    axs[2].imshow(y_pred[idx])
    axs[2].set_title("Prediction")
    plt.show()

# %% [markdown]
# Functions to plot the learning curve of a model and its confusion matrix

# %%
def plot_learning_curve(history):
  plt.figure(figsize=(12, 4))

  # Plot training and validation loss
  plt.subplot(1, 2, 1)
  plt.plot(history.history['loss'], label='Training Loss')
  plt.plot(history.history['val_loss'], label='Validation Loss')
  plt.title('Model Loss')
  plt.xlabel('Epoch')
  plt.ylabel('Loss')
  plt.legend()

  # Plot training and validation accuracy
  plt.subplot(1, 2, 2)
  plt.plot(history.history['accuracy'], label='Training Accuracy')
  plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
  plt.title('Model Accuracy')
  plt.xlabel('Epoch')
  plt.ylabel('Accuracy')
  plt.legend()

  plt.show()

# %%
def plot_confusion_matrix(y_true, y_pred, num_classes):
  # Compute the confusion matrix
  cm = confusion_matrix(y_test.reshape(-1), y_pred.numpy().reshape(-1))

  # Plot the confusion matrix
  disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=[f'Class {i}' for i in range(num_classes)])
  disp.plot(cmap=plt.cm.Blues)
  plt.title('Confusion Matrix')
  plt.show()

# %% [markdown]
# ##Model Architecture
# I'm using a Fully Convolutional Neural Network to solve the task, having both as input and as output images. So I have to build the structure of the encoder and that of the decoder, connecting them through a bottleneck. For this scope I will only include in the network layers of the following kinds: Conv2d, MaxPool2d, Conv2dTranspose and Concatenate layers to include the skip connections in the network.
# I will firstly define a convolutional block and an transpose convolutional block which I will use as main components respectively of the encoder and of the decoder; in this way it will be easier to scale up the model if needed
#
# **Also, as comments, I added Bropout and BatchNormalization layers which could help reaching better results in the long run, I didn't actually add them to my model since I did not talk about them in the written part of the exam, but I wanted to highlight that they might be helpful in a unconstrained setting**

# %%
# CONVOLUTIONAL BLOCK
# I'm assuming that the blocks have a fixed number of layers (2 Conv2D, 1 MaxPool2D)
# and that all the layers in the block have the same number of filters (n_filters)
# Dropout and BatchNormalization layer because they are possible ways to get a better model but I did not mention them in the written part of the exam

def convolutional_block(x, n_filters:int, kernel_size:tuple[int]=(3, 3), padding:str="same", pool_size:tuple[int]=(2,2)):
  conv = Conv2D(n_filters, kernel_size=kernel_size, padding=padding, activation='relu', kernel_initializer='he_normal')(x)
  #conv = Dropout(.3)(conv)
  conv = Conv2D(n_filters, kernel_size=kernel_size, padding=padding, activation='relu', kernel_initializer='he_normal')(conv)
  #conv = BatchNormalization()(conv, training=False)

  pool = MaxPool2D(pool_size=pool_size)(conv)

  return conv, pool

# TRANSPOSE CONVOLUTIONAL BLOCK
# I'm assuming that the blocks have a fixed number of layers (1 Conv2DTranspose, 2 Conv2D + skip connection)
# and that all the Conv2D layers in the block have the same number of filters (n_filters_conv);

def transpose_block(x, skip, n_filters:int, kernel_size:tuple[int]=(3, 3), padding:str="same", stride_trans:tuple[int]=(2,2)):
  trans_conv = Conv2DTranspose(n_filters, kernel_size=(2,2), strides=stride_trans, padding=padding)(x)
  conc = Concatenate()([skip, trans_conv])
  conv = Conv2D(n_filters, kernel_size=kernel_size, padding=padding, activation='relu', kernel_initializer='he_normal')(conc)
  #conv = Dropout(.3)(conv)
  conv = Conv2D(n_filters, kernel_size=kernel_size, padding=padding, activation='relu', kernel_initializer='he_normal')(conv)

  return conv

# %%
def FCNN(img_shape:tuple[int], n_classes:int, n_filters_list:list[int], \
         kernel_size:tuple[int]=(3, 3), padding:str="same", pool_size:tuple[int]=(2,2)):
  input = Input(shape=img_shape)
  conv_layers = []
  pool_layers = []
  decoder_layers = []

  # ENCODER
  for i, n_filters in enumerate(n_filters_list):
    if i == 0:
      conv, pool = convolutional_block(input, n_filters, kernel_size, padding, pool_size)
      conv_layers.append(conv)
      pool_layers.append(pool)
    else:
      conv, pool = convolutional_block(pool_layers[-1], n_filters, kernel_size, padding, pool_size)
      conv_layers.append(conv)
      pool_layers.append(pool)

  # BOTTLENECK
  # I'm assuming a fixed size bottleneck with 2 layers
  # with the same number of filters of the last encoding block (or first decoding block)
  bot = Conv2D(n_filters_list[-1], kernel_size=kernel_size, padding=padding, activation='relu', kernel_initializer='he_normal')(pool_layers[-1])
  bot = Conv2D(n_filters_list[-1], kernel_size=kernel_size, padding=padding, activation='relu', kernel_initializer='he_normal')(bot)

  # DECODER
  for i, n_filters in enumerate(n_filters_list):
    if i == 0:
      conv = transpose_block(bot, conv_layers[-(i+1)], n_filters_list[-(i+1)], kernel_size, padding)
      decoder_layers.append(conv)
    else:
      conv = transpose_block(decoder_layers[-1], conv_layers[-(i+1)], n_filters_list[-(i+1)], kernel_size, padding)
      decoder_layers.append(conv)

  # OUTPUT layers
  output = Conv2D(n_classes, kernel_size=(1,1), padding=padding, activation='softmax')(decoder_layers[-1])

  model = Model(inputs=[input], outputs=[output])
  model.compile(optimizer='Adam', loss='sparse_categorical_crossentropy', metrics=['accuracy', CustomMeanIoU(num_classes=n_classes, name='IoU')])
  return model

# %% [markdown]
# ##Base Model
# Now I train a base model and evaluate his performance to keep it as term of comparison later in the work. In this stage I'm not trying to optimize any parameter.

# %%
n_filters_list = [16, 32, 64]
model = FCNN(img_shape=img_shape,
             n_classes=n_classes,
             n_filters_list=n_filters_list)

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  conv2d (Conv2D)             (None, 256, 256, 16)         448       ['input_1[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 256, 256, 16)         2320      ['conv2d[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 128, 128, 16)         0         ['conv2d_1[0][0]']
#  D)
#
#  conv2d_2 (Conv2D)           (None, 128, 128, 32)         4640      ['max_pooling2d[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 128, 128, 32)         9248      ['conv2d_2[0][0]']
#
#  max_pooling2d_1 (MaxPoolin  (None, 64, 64, 32)           0         ['conv2d_3[0][0]']
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 64, 64, 64)           18496     ['max_pooling2d_1[0][0]']
#
#  conv2d_5 (Conv2D)           (None, 64, 64, 64)           36928     ['conv2d_4[0][0]']
#
#  max_pooling2d_2 (MaxPoolin  (None, 32, 32, 64)           0         ['conv2d_5[0][0]']
#  g2D)
#
#  conv2d_6 (Conv2D)           (None, 32, 32, 64)           36928     ['max_pooling2d_2[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 32, 32, 64)           36928     ['conv2d_6[0][0]']
#
#  conv2d_transpose (Conv2DTr  (None, 64, 64, 64)           16448     ['conv2d_7[0][0]']
#  anspose)
#
#  concatenate (Concatenate)   (None, 64, 64, 128)          0         ['conv2d_5[0][0]',
#                                                                      'conv2d_transpose[0][0]']
#
#  conv2d_8 (Conv2D)           (None, 64, 64, 64)           73792     ['concatenate[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 64, 64, 64)           36928     ['conv2d_8[0][0]']
#
#  conv2d_transpose_1 (Conv2D  (None, 128, 128, 32)         8224      ['conv2d_9[0][0]']
#  Transpose)
#
#  concatenate_1 (Concatenate  (None, 128, 128, 64)         0         ['conv2d_3[0][0]',
#  )                                                                   'conv2d_transpose_1[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 128, 128, 32)         18464     ['concatenate_1[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 128, 128, 32)         9248      ['conv2d_10[0][0]']
#
#  conv2d_transpose_2 (Conv2D  (None, 256, 256, 16)         2064      ['conv2d_11[0][0]']
#  Transpose)
#
#  concatenate_2 (Concatenate  (None, 256, 256, 32)         0         ['conv2d_1[0][0]',
#  )                                                                   'conv2d_transpose_2[0][0]']
#
#  conv2d_12 (Conv2D)          (None, 256, 256, 16)         4624      ['concatenate_2[0][0]']
#
#  conv2d_13 (Conv2D)          (None, 256, 256, 16)         2320      ['conv2d_12[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 256, 256, 6)          102       ['conv2d_13[0][0]']
#
# ==================================================================================================
# Total params: 318150 (1.21 MB)
# Trainable params: 318150 (1.21 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
model.fit(X_train, y_train, batch_size=32, epochs=10, class_weight=class_weights)
# Out:
# Epoch 1/10
# 33/33 [==============================] - 36s 487ms/step - loss: 1.6954 - accuracy: 0.4790 - IoU: 0.1670
# Epoch 2/10
# 33/33 [==============================] - 9s 267ms/step - loss: 1.4305 - accuracy: 0.5985 - IoU: 0.3264
# Epoch 3/10
# 33/33 [==============================] - 9s 264ms/step - loss: 1.2536 - accuracy: 0.6277 - IoU: 0.3723
# Epoch 4/10
# 33/33 [==============================] - 9s 261ms/step - loss: 1.1768 - accuracy: 0.6649 - IoU: 0.3908
# Epoch 5/10
# 33/33 [==============================] - 9s 258ms/step - loss: 1.1354 - accuracy: 0.6456 - IoU: 0.4081
# Epoch 6/10
# 33/33 [==============================] - 9s 259ms/step - loss: 1.0969 - accuracy: 0.6328 - IoU: 0.4067
# Epoch 7/10
# 33/33 [==============================] - 9s 265ms/step - loss: 1.0616 - accuracy: 0.6603 - IoU: 0.4361
# Epoch 8/10
# 33/33 [==============================] - 9s 264ms/step - loss: 1.0729 - accuracy: 0.6921 - IoU: 0.4466
# Epoch 9/10
# 33/33 [==============================] - 9s 258ms/step - loss: 1.0243 - accuracy: 0.6815 - IoU: 0.4630
# Epoch 10/10
# 33/33 [==============================] - 9s 262ms/step - loss: 0.9747 - accuracy: 0.6879 - IoU: 0.4760

# %%
y_hat = model.predict(X_test)
y_pred = tf.expand_dims(tf.argmax(y_hat, axis=-1), axis=-1)
# Out:
# 9/9 [==============================] - 2s 181ms/step

# %%
print(accuracy_score(y_test.reshape(-1), y_pred.numpy().reshape(-1)))
m_iou = CustomMeanIoU(num_classes=n_classes)
m_iou.update_state(y_test, y_hat)
print(m_iou.result().numpy())
# Out:
# 0.711431919843301
# 0.46632215

# %% [markdown]
# ##Hyperparameter Tuning
# While I'm displaying both accuracy and Intersection over Union as performance metrics \\
# **I will only consider accuracy since I did not mention Intersection over Union in the written part of the exam** \\
# It would be preferable, though, due to the semantic segmentation nature of the task, to take Intersection over Union in consideration as main metric

# %%
param_grid = {
    'n_filters_list' : [[16,32], [32, 64], [64, 128], [16, 32, 64], [32, 64, 128], [16, 32, 64, 128]],
    'batch_size' : [8, 16, 32]
}

# %% [markdown]
# I'm writing a custom grid_search since the scikit_learn implementation is not optimal for handling image kind of data, in particular the wrappers (KerasClassifier) may not work correctly for this sake. \\
# While performing the grid search I'm storing the four best models found

# %%
def grid_search(model_func, img_shape, n_classes, param_grid, X, y, epochs, val_size=.2, random_state=42):
  # Generate all combinations of parameters
  param_combinations = list(itertools.product(*param_grid.values()))
  print(f'Searching in {len(param_combinations)} combinations')

  # Keep track of the four best results
  best_models = []

  X_tra, X_val, y_tra, y_val = train_test_split(X, y, test_size=val_size, shuffle=True,random_state=random_state)
  class_weights = get_class_weights(y_tra)

  for idx, params in enumerate(param_combinations):
    current_params = dict(zip(param_grid.keys(), params))
    print(f'Configuration {idx+1}/{len(param_combinations)} -> current parameters: ', current_params)
    batch_size = current_params.pop('batch_size')
    model = model_func(img_shape=img_shape, n_classes=n_classes,
                  n_filters_list=current_params['n_filters_list'])

    # Evaluating the current model
    print('Evaluating...')
    val_loss, val_acc, val_iou = evaluate_model(model, X_tra, y_tra, X_val, y_val, class_weights, batch_size, epochs)
    print(f'Validation accuracy: {val_acc}, Validation IoU: {val_iou}')

    # Here I'm only considering accuracy to select the best model
    if len(best_models) < 4:
      best_models.append({**current_params, 'batch_size': batch_size, 'score' : val_acc})
    elif val_acc > min([i['score'] for i in best_models]):
      best_models.append({**current_params, 'batch_size': batch_size, 'score' : val_acc})
      best_models.remove(min(best_models, key=lambda x: x['score']))

  print('Best models: ')
  for model in best_models:
    print(model)

  return best_models

# %%
# Partial datasets to be de-commented in case of hardware constraints
partial_X_train = X_train[:400]
partial_y_train = y_train[:400]

best_models = grid_search(model_func=FCNN,
                          img_shape=img_shape,
                          n_classes=n_classes,
                          param_grid=param_grid,
                          X=partial_X_train,
                          y=partial_y_train,
                          epochs=6)
# Out:
# Searching in 18 combinations
# Configuration 1/18 -> current parameters:  {'n_filters_list': [16, 32], 'batch_size': 8}
# Evaluating...
# Epoch 1/6
# 40/40 [==============================] - 13s 60ms/step - loss: 1.7178 - accuracy: 0.5138 - IoU: 0.1531
# Epoch 2/6
# 40/40 [==============================] - 2s 59ms/step - loss: 1.6478 - accuracy: 0.5350 - IoU: 0.2374
# Epoch 3/6
# 40/40 [==============================] - 3s 65ms/step - loss: 1.3676 - accuracy: 0.6373 - IoU: 0.3129
# Epoch 4/6
# 40/40 [==============================] - 2s 60ms/step - loss: 1.2561 - accuracy: 0.5651 - IoU: 0.3259
# Epoch 5/6
# 40/40 [==============================] - 2s 59ms/step - loss: 1.2338 - accuracy: 0.5234 - IoU: 0.3236
# Epoch 6/6
# 40/40 [==============================] - 2s 59ms/step - loss: 1.1994 - accuracy: 0.6213 - IoU: 0.3632
# Validation accuracy: 0.7478437423706055, Validation IoU: 0.4247570037841797
# Configuration 2/18 -> current parameters:  {'n_filters_list': [16, 32], 'batch_size': 16}
# Evaluating...
# Epoch 1/6
# 20/20 [==============================] - 12s 122ms/step - loss: 1.7799 - accuracy: 0.3208 - IoU: 0.0941
# Epoch 2/6
# 20/20 [==============================] - 2s 121ms/step - loss: 1.6625 - accuracy: 0.5084 - IoU: 0.1910
# Epoch 3/6
# 20/20 [==============================] - 2s 120ms/step - loss: 1.5270 - accuracy: 0.6490 - IoU: 0.3083
# Epoch 4/6
# 20/20 [==============================] - 3s 127ms/step - loss: 1.3141 - accuracy: 0.6804 - IoU: 0.3437
# Epoch 5/6
# 20/20 [==============================] - 3s 126ms/step - loss: 1.2176 - accuracy: 0.6237 - IoU: 0.3515
# Epoch 6/6
# 20/20 [==============================] - 2s 121ms/step - loss: 1.1628 - accuracy: 0.6551 - IoU: 0.3922
# Validation accuracy: 0.6936429738998413, Validation IoU: 0.39682555198669434
# Configuration 3/18 -> current parameters:  {'n_filters_list': [16, 32], 'batch_size': 32}
# Evaluating...
# Epoch 1/6
# 10/10 [==============================] - 16s 252ms/step - loss: 1.7749 - accuracy: 0.2457 - IoU: 0.0895
# Epoch 2/6
# 10/10 [==============================] - 3s 259ms/step - loss: 1.6830 - accuracy: 0.4770 - IoU: 0.1792
# Epoch 3/6
# 10/10 [==============================] - 3s 256ms/step - loss: 1.6125 - accuracy: 0.5731 - IoU: 0.2558
# Epoch 4/6
# 10/10 [==============================] - 2s 245ms/step - loss: 1.4819 - accuracy: 0.5918 - IoU: 0.3125
# Epoch 5/6
# 10/10 [==============================] - 2s 246ms/step - loss: 1.2962 - accuracy: 0.6428 - IoU: 0.3438
# Epoch 6/6
# 10/10 [==============================] - 2s 245ms/step - loss: 1.2218 - accuracy: 0.6950 - IoU: 0.3834
# Validation accuracy: 0.6134130358695984, Validation IoU: 0.29841187596321106
# Configuration 4/18 -> current parameters:  {'n_filters_list': [32, 64], 'batch_size': 8}
# Evaluating...
# Epoch 1/6
# 40/40 [==============================] - 15s 106ms/step - loss: 1.7099 - accuracy: 0.4506 - IoU: 0.1516
# Epoch 2/6
# 40/40 [==============================] - 4s 106ms/step - loss: 1.4349 - accuracy: 0.5862 - IoU: 0.3059
# Epoch 3/6
# 40/40 [==============================] - 4s 110ms/step - loss: 1.2742 - accuracy: 0.5505 - IoU: 0.3354
# Epoch 4/6
# 40/40 [==============================] - 4s 108ms/step - loss: 1.2447 - accuracy: 0.6092 - IoU: 0.3537
# Epoch 5/6
# 40/40 [==============================] - 4s 108ms/step - loss: 1.1751 - accuracy: 0.6902 - IoU: 0.4023
# Epoch 6/6
# 40/40 [==============================] - 4s 111ms/step - loss: 1.1039 - accuracy: 0.6877 - IoU: 0.4096
# Validation accuracy: 0.7316457629203796, Validation IoU: 0.4655977189540863
# Configuration 5/18 -> current parameters:  {'n_filters_list': [32, 64], 'batch_size': 16}
# Evaluating...
# Epoch 1/6
# 20/20 [==============================] - 19s 218ms/step - loss: 1.7152 - accuracy: 0.1752 - IoU: 0.0794
# Epoch 2/6
# 20/20 [==============================] - 4s 214ms/step - loss: 1.5940 - accuracy: 0.5981 - IoU: 0.2636
# Epoch 3/6
# 20/20 [==============================] - 4s 217ms/step - loss: 1.3873 - accuracy: 0.6125 - IoU: 0.3124
# Epoch 4/6
# 20/20 [==============================] - 4s 214ms/step - loss: 1.3275 - accuracy: 0.5942 - IoU: 0.3370
# Epoch 5/6
# 20/20 [==============================] - 4s 212ms/step - loss: 1.2179 - accuracy: 0.6580 - IoU: 0.3676
# Epoch 6/6
# 20/20 [==============================] - 4s 217ms/step - loss: 1.1901 - accuracy: 0.6597 - IoU: 0.3878
# Validation accuracy: 0.7102502584457397, Validation IoU: 0.40949705243110657
# Configuration 6/18 -> current parameters:  {'n_filters_list': [32, 64], 'batch_size': 32}
# Evaluating...
# Epoch 1/6
# 10/10 [==============================] - 27s 501ms/step - loss: 1.7824 - accuracy: 0.1665 - IoU: 0.0603
# Epoch 2/6
# 10/10 [==============================] - 5s 513ms/step - loss: 1.6816 - accuracy: 0.5249 - IoU: 0.1654
# Epoch 3/6
# 10/10 [==============================] - 5s 519ms/step - loss: 1.5755 - accuracy: 0.5564 - IoU: 0.2242
# Epoch 4/6
# 10/10 [==============================] - 5s 454ms/step - loss: 1.4763 - accuracy: 0.6266 - IoU: 0.3050
# Epoch 5/6
# 10/10 [==============================] - 4s 449ms/step - loss: 1.3277 - accuracy: 0.5745 - IoU: 0.3087
# Epoch 6/6
# 10/10 [==============================] - 4s 441ms/step - loss: 1.2662 - accuracy: 0.6196 - IoU: 0.3416
# Validation accuracy: 0.5158780813217163, Validation IoU: 0.32806575298309326
# Configuration 7/18 -> current parameters:  {'n_filters_list': [64, 128], 'batch_size': 8}
# Evaluating...
# Epoch 1/6
# 40/40 [==============================] - 25s 264ms/step - loss: 1.7912 - accuracy: 0.3293 - IoU: 0.1344
# Epoch 2/6
# 40/40 [==============================] - 11s 272ms/step - loss: 1.4657 - accuracy: 0.5786 - IoU: 0.2966
# Epoch 3/6
# 40/40 [==============================] - 11s 264ms/step - loss: 1.3056 - accuracy: 0.6322 - IoU: 0.3450
# Epoch 4/6
# 40/40 [==============================] - 10s 255ms/step - loss: 1.2384 - accuracy: 0.6286 - IoU: 0.3608
# Epoch 5/6
# 40/40 [==============================] - 10s 250ms/step - loss: 1.1988 - accuracy: 0.6804 - IoU: 0.3810
# Epoch 6/6
# 40/40 [==============================] - 10s 249ms/step - loss: 1.1995 - accuracy: 0.6348 - IoU: 0.3888
# Validation accuracy: 0.6678468585014343, Validation IoU: 0.423626571893692
# Configuration 8/18 -> current parameters:  {'n_filters_list': [64, 128], 'batch_size': 16}
# Evaluating...
# Epoch 1/6
# 20/20 [==============================] - 31s 480ms/step - loss: 1.7254 - accuracy: 0.3350 - IoU: 0.1140
# Epoch 2/6
# 20/20 [==============================] - 9s 474ms/step - loss: 1.5178 - accuracy: 0.6351 - IoU: 0.2859
# Epoch 3/6
# 20/20 [==============================] - 9s 473ms/step - loss: 1.3227 - accuracy: 0.5702 - IoU: 0.3073
# Epoch 4/6
# 20/20 [==============================] - 9s 472ms/step - loss: 1.3276 - accuracy: 0.6078 - IoU: 0.3306
# Epoch 5/6
# 20/20 [==============================] - 9s 459ms/step - loss: 1.2981 - accuracy: 0.5616 - IoU: 0.3228
# Epoch 6/6
# 20/20 [==============================] - 9s 455ms/step - loss: 1.1802 - accuracy: 0.5482 - IoU: 0.3498
# Validation accuracy: 0.7152097821235657, Validation IoU: 0.4030797481536865
# Configuration 9/18 -> current parameters:  {'n_filters_list': [64, 128], 'batch_size': 32}
# Evaluating...
# Epoch 1/6
# 10/10 [==============================] - 46s 980ms/step - loss: 1.7680 - accuracy: 0.4413 - IoU: 0.1246
# Epoch 2/6
# 10/10 [==============================] - 9s 932ms/step - loss: 1.6595 - accuracy: 0.5980 - IoU: 0.2132
# Epoch 3/6
# 10/10 [==============================] - 9s 922ms/step - loss: 1.5347 - accuracy: 0.5435 - IoU: 0.2781
# Epoch 4/6
# 10/10 [==============================] - 9s 935ms/step - loss: 1.3153 - accuracy: 0.6861 - IoU: 0.3526
# Epoch 5/6
# 10/10 [==============================] - 9s 947ms/step - loss: 1.1933 - accuracy: 0.6467 - IoU: 0.3793
# Epoch 6/6
# 10/10 [==============================] - 9s 945ms/step - loss: 1.1489 - accuracy: 0.7060 - IoU: 0.4133
# Validation accuracy: 0.762438178062439, Validation IoU: 0.4561469554901123
# Configuration 10/18 -> current parameters:  {'n_filters_list': [16, 32, 64], 'batch_size': 8}
# Evaluating...
# Epoch 1/6
# 40/40 [==============================] - 10s 70ms/step - loss: 1.7435 - accuracy: 0.4172 - IoU: 0.1100
# Epoch 2/6
# 40/40 [==============================] - 3s 70ms/step - loss: 1.6775 - accuracy: 0.2774 - IoU: 0.1041
# Epoch 3/6
# 40/40 [==============================] - 3s 72ms/step - loss: 1.5559 - accuracy: 0.5700 - IoU: 0.2798
# Epoch 4/6
# 40/40 [==============================] - 3s 73ms/step - loss: 1.4562 - accuracy: 0.6663 - IoU: 0.3125
# Epoch 5/6
# 40/40 [==============================] - 3s 70ms/step - loss: 1.2887 - accuracy: 0.6543 - IoU: 0.3663
# Epoch 6/6
# 40/40 [==============================] - 3s 70ms/step - loss: 1.2015 - accuracy: 0.6192 - IoU: 0.3756
# Validation accuracy: 0.7270887494087219, Validation IoU: 0.43004241585731506
# Configuration 11/18 -> current parameters:  {'n_filters_list': [16, 32, 64], 'batch_size': 16}
# Evaluating...
# Epoch 1/6
# 20/20 [==============================] - 10s 138ms/step - loss: 1.7687 - accuracy: 0.4129 - IoU: 0.1235
# Epoch 2/6
# 20/20 [==============================] - 3s 138ms/step - loss: 1.6568 - accuracy: 0.4541 - IoU: 0.1716
# Epoch 3/6
# 20/20 [==============================] - 3s 138ms/step - loss: 1.6754 - accuracy: 0.4532 - IoU: 0.1647
# Epoch 4/6
# 20/20 [==============================] - 3s 148ms/step - loss: 1.4944 - accuracy: 0.6450 - IoU: 0.2854
# Epoch 5/6
# 20/20 [==============================] - 3s 141ms/step - loss: 1.3866 - accuracy: 0.5895 - IoU: 0.3026
# Epoch 6/6
# 20/20 [==============================] - 3s 140ms/step - loss: 1.3175 - accuracy: 0.4849 - IoU: 0.2933
# Validation accuracy: 0.720598042011261, Validation IoU: 0.37912365794181824
# Configuration 12/18 -> current parameters:  {'n_filters_list': [16, 32, 64], 'batch_size': 32}
# Evaluating...
# Epoch 1/6
# 10/10 [==============================] - 10s 282ms/step - loss: 1.7386 - accuracy: 0.0578 - IoU: 0.0387
# Epoch 2/6
# 10/10 [==============================] - 3s 277ms/step - loss: 1.6840 - accuracy: 0.2944 - IoU: 0.1473
# Epoch 3/6
# 10/10 [==============================] - 3s 278ms/step - loss: 1.6001 - accuracy: 0.5263 - IoU: 0.2308
# Epoch 4/6
# 10/10 [==============================] - 3s 297ms/step - loss: 1.5228 - accuracy: 0.6392 - IoU: 0.2517
# Epoch 5/6
# 10/10 [==============================] - 3s 279ms/step - loss: 1.4803 - accuracy: 0.6310 - IoU: 0.2867
# Epoch 6/6
# 10/10 [==============================] - 3s 276ms/step - loss: 1.3746 - accuracy: 0.6254 - IoU: 0.2961
# Validation accuracy: 0.5558282732963562, Validation IoU: 0.2841198444366455
# Configuration 13/18 -> current parameters:  {'n_filters_list': [32, 64, 128], 'batch_size': 8}
# Evaluating...
# Epoch 1/6
# 40/40 [==============================] - 13s 131ms/step - loss: 1.7691 - accuracy: 0.4622 - IoU: 0.1536
# Epoch 2/6
# 40/40 [==============================] - 5s 131ms/step - loss: 1.4420 - accuracy: 0.6221 - IoU: 0.3115
# Epoch 3/6
# 40/40 [==============================] - 5s 134ms/step - loss: 1.3220 - accuracy: 0.5885 - IoU: 0.3299
# Epoch 4/6
# 40/40 [==============================] - 5s 132ms/step - loss: 1.2241 - accuracy: 0.6310 - IoU: 0.3647
# Epoch 5/6
# 40/40 [==============================] - 5s 135ms/step - loss: 1.2367 - accuracy: 0.5978 - IoU: 0.3694
# Epoch 6/6
# 40/40 [==============================] - 5s 133ms/step - loss: 1.1422 - accuracy: 0.6380 - IoU: 0.3985
# Validation accuracy: 0.699672520160675, Validation IoU: 0.46075427532196045
# Configuration 14/18 -> current parameters:  {'n_filters_list': [32, 64, 128], 'batch_size': 16}
# Evaluating...
# Epoch 1/6
# 20/20 [==============================] - 13s 255ms/step - loss: 1.8360 - accuracy: 0.1356 - IoU: 0.0598
# Epoch 2/6
# 20/20 [==============================] - 5s 258ms/step - loss: 1.7146 - accuracy: 0.2580 - IoU: 0.1340
# Epoch 3/6
# 20/20 [==============================] - 5s 250ms/step - loss: 1.6395 - accuracy: 0.5971 - IoU: 0.2427
# Epoch 4/6
# 20/20 [==============================] - 5s 256ms/step - loss: 1.5601 - accuracy: 0.4751 - IoU: 0.2493
# Epoch 5/6
# 20/20 [==============================] - 5s 250ms/step - loss: 1.3594 - accuracy: 0.6798 - IoU: 0.3413
# Epoch 6/6
# 20/20 [==============================] - 5s 250ms/step - loss: 1.2716 - accuracy: 0.6153 - IoU: 0.3432
# Validation accuracy: 0.6971298456192017, Validation IoU: 0.38411983847618103
# Configuration 15/18 -> current parameters:  {'n_filters_list': [32, 64, 128], 'batch_size': 32}
# Evaluating...
# Epoch 1/6
# 10/10 [==============================] - 15s 544ms/step - loss: 1.7300 - accuracy: 0.3523 - IoU: 0.0959
# Epoch 2/6
# 10/10 [==============================] - 5s 534ms/step - loss: 1.6294 - accuracy: 0.2461 - IoU: 0.0958
# Epoch 3/6
# 10/10 [==============================] - 5s 546ms/step - loss: 1.5980 - accuracy: 0.5385 - IoU: 0.1937
# Epoch 4/6
# 10/10 [==============================] - 5s 548ms/step - loss: 1.5258 - accuracy: 0.5554 - IoU: 0.2798
# Epoch 5/6
# 10/10 [==============================] - 6s 553ms/step - loss: 1.3617 - accuracy: 0.6743 - IoU: 0.3342
# Epoch 6/6
# 10/10 [==============================] - 5s 536ms/step - loss: 1.3098 - accuracy: 0.6692 - IoU: 0.3574
# Validation accuracy: 0.7083202600479126, Validation IoU: 0.4169963598251343
# Configuration 16/18 -> current parameters:  {'n_filters_list': [16, 32, 64, 128], 'batch_size': 8}
# Evaluating...
# Epoch 1/6
# 40/40 [==============================] - 11s 76ms/step - loss: 1.7664 - accuracy: 0.4090 - IoU: 0.1340
# Epoch 2/6
# 40/40 [==============================] - 3s 76ms/step - loss: 1.5716 - accuracy: 0.6249 - IoU: 0.2697
# Epoch 3/6
# 40/40 [==============================] - 3s 79ms/step - loss: 1.4222 - accuracy: 0.4915 - IoU: 0.2413
# Epoch 4/6
# 40/40 [==============================] - 3s 76ms/step - loss: 1.3628 - accuracy: 0.5591 - IoU: 0.2889
# Epoch 5/6
# 40/40 [==============================] - 3s 75ms/step - loss: 1.2879 - accuracy: 0.6528 - IoU: 0.3487
# Epoch 6/6
# 40/40 [==============================] - 3s 76ms/step - loss: 1.2432 - accuracy: 0.6844 - IoU: 0.3748
# Validation accuracy: 0.6267539858818054, Validation IoU: 0.37544575333595276
# Configuration 17/18 -> current parameters:  {'n_filters_list': [16, 32, 64, 128], 'batch_size': 16}
# Evaluating...
# Epoch 1/6
# 20/20 [==============================] - 11s 148ms/step - loss: 1.7762 - accuracy: 0.4022 - IoU: 0.1191
# Epoch 2/6
# 20/20 [==============================] - 3s 149ms/step - loss: 1.6585 - accuracy: 0.6035 - IoU: 0.2018
# Epoch 3/6
# 20/20 [==============================] - 3s 151ms/step - loss: 1.5898 - accuracy: 0.6716 - IoU: 0.3073
# Epoch 4/6
# 20/20 [==============================] - 3s 158ms/step - loss: 1.4485 - accuracy: 0.7009 - IoU: 0.3408
# Epoch 5/6
# 20/20 [==============================] - 3s 151ms/step - loss: 1.3881 - accuracy: 0.6847 - IoU: 0.3280
# Epoch 6/6
# 20/20 [==============================] - 3s 151ms/step - loss: 1.2490 - accuracy: 0.7247 - IoU: 0.3657
# Validation accuracy: 0.7191058993339539, Validation IoU: 0.3803584575653076
# Configuration 18/18 -> current parameters:  {'n_filters_list': [16, 32, 64, 128], 'batch_size': 32}
# Evaluating...
# Epoch 1/6
# 10/10 [==============================] - 12s 304ms/step - loss: 1.7651 - accuracy: 0.2307 - IoU: 0.0769
# Epoch 2/6
# 10/10 [==============================] - 3s 309ms/step - loss: 1.6752 - accuracy: 0.5440 - IoU: 0.1495
# Epoch 3/6
# 10/10 [==============================] - 3s 314ms/step - loss: 1.6104 - accuracy: 0.5647 - IoU: 0.1873
# Epoch 4/6
# 10/10 [==============================] - 3s 301ms/step - loss: 1.5598 - accuracy: 0.5854 - IoU: 0.2277
# Epoch 5/6
# 10/10 [==============================] - 3s 300ms/step - loss: 1.5255 - accuracy: 0.6150 - IoU: 0.2721
# Epoch 6/6
# 10/10 [==============================] - 3s 300ms/step - loss: 1.4241 - accuracy: 0.6401 - IoU: 0.3249
# Validation accuracy: 0.6355144381523132, Validation IoU: 0.3162693977355957
# Best models:
# {'n_filters_list': [16, 32], 'batch_size': 8, 'score': 0.7478437423706055}
# {'n_filters_list': [32, 64], 'batch_size': 8, 'score': 0.7316457629203796}
# {'n_filters_list': [64, 128], 'batch_size': 32, 'score': 0.762438178062439}
# {'n_filters_list': [16, 32, 64], 'batch_size': 8, 'score': 0.7270887494087219}

# %%
clear_session()

# %% [markdown]
# ##Refitting the best model on the full training dataset

# %%
best_params = best_models[2]

# %%
best_model = FCNN(img_shape,
                  n_classes,
                  n_filters_list=best_params['n_filters_list'])

# %%
best_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  conv2d (Conv2D)             (None, 256, 256, 64)         1792      ['input_1[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 256, 256, 64)         36928     ['conv2d[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 128, 128, 64)         0         ['conv2d_1[0][0]']
#  D)
#
#  conv2d_2 (Conv2D)           (None, 128, 128, 128)        73856     ['max_pooling2d[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 128, 128, 128)        147584    ['conv2d_2[0][0]']
#
#  max_pooling2d_1 (MaxPoolin  (None, 64, 64, 128)          0         ['conv2d_3[0][0]']
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 64, 64, 128)          147584    ['max_pooling2d_1[0][0]']
#
#  conv2d_5 (Conv2D)           (None, 64, 64, 128)          147584    ['conv2d_4[0][0]']
#
#  conv2d_transpose (Conv2DTr  (None, 128, 128, 128)        65664     ['conv2d_5[0][0]']
#  anspose)
#
#  concatenate (Concatenate)   (None, 128, 128, 256)        0         ['conv2d_3[0][0]',
#                                                                      'conv2d_transpose[0][0]']
#
#  conv2d_6 (Conv2D)           (None, 128, 128, 128)        295040    ['concatenate[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 128, 128, 128)        147584    ['conv2d_6[0][0]']
#
#  conv2d_transpose_1 (Conv2D  (None, 256, 256, 64)         32832     ['conv2d_7[0][0]']
#  Transpose)
#
#  concatenate_1 (Concatenate  (None, 256, 256, 128)        0         ['conv2d_1[0][0]',
#  )                                                                   'conv2d_transpose_1[0][0]']
#
#  conv2d_8 (Conv2D)           (None, 256, 256, 64)         73792     ['concatenate_1[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 256, 256, 64)         36928     ['conv2d_8[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 256, 256, 6)          390       ['conv2d_9[0][0]']
#
# ==================================================================================================
# Total params: 1207558 (4.61 MB)
# Trainable params: 1207558 (4.61 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss',
                                            patience=12,
                                            mode='min',
                                            restore_best_weights=True)

history = best_model.fit(X_train, y_train, batch_size=best_params['batch_size'], epochs=100, class_weight=class_weights, validation_split=.2, callbacks=[callback])
# Out:
# Epoch 1/100
# 27/27 [==============================] - 82s 2s/step - loss: 1.7344 - accuracy: 0.4580 - IoU: 0.1732 - val_loss: 1.2335 - val_accuracy: 0.6416 - val_IoU: 0.3098
# Epoch 2/100
# 27/27 [==============================] - 26s 967ms/step - loss: 1.3261 - accuracy: 0.6153 - IoU: 0.3134 - val_loss: 1.3834 - val_accuracy: 0.2689 - val_IoU: 0.2659
# Epoch 3/100
# 27/27 [==============================] - 26s 976ms/step - loss: 1.2013 - accuracy: 0.6043 - IoU: 0.3633 - val_loss: 0.9657 - val_accuracy: 0.7156 - val_IoU: 0.4091
# Epoch 4/100
# 27/27 [==============================] - 27s 1s/step - loss: 1.1143 - accuracy: 0.6873 - IoU: 0.4206 - val_loss: 1.3699 - val_accuracy: 0.3124 - val_IoU: 0.2791
# Epoch 5/100
# 27/27 [==============================] - 27s 998ms/step - loss: 1.1747 - accuracy: 0.4796 - IoU: 0.3669 - val_loss: 1.1578 - val_accuracy: 0.6188 - val_IoU: 0.4126
# Epoch 6/100
# 27/27 [==============================] - 27s 1s/step - loss: 1.0249 - accuracy: 0.6778 - IoU: 0.4444 - val_loss: 1.0158 - val_accuracy: 0.6995 - val_IoU: 0.4190
# Epoch 7/100
# 27/27 [==============================] - 27s 992ms/step - loss: 1.0843 - accuracy: 0.7022 - IoU: 0.4423 - val_loss: 0.9468 - val_accuracy: 0.7107 - val_IoU: 0.4614
# Epoch 8/100
# 27/27 [==============================] - 27s 986ms/step - loss: 0.9769 - accuracy: 0.6822 - IoU: 0.4611 - val_loss: 1.0291 - val_accuracy: 0.6769 - val_IoU: 0.4471
# Epoch 9/100
# 27/27 [==============================] - 26s 978ms/step - loss: 0.9417 - accuracy: 0.7111 - IoU: 0.4794 - val_loss: 0.8439 - val_accuracy: 0.7456 - val_IoU: 0.4983
# Epoch 10/100
# 27/27 [==============================] - 27s 1s/step - loss: 0.9439 - accuracy: 0.7263 - IoU: 0.4877 - val_loss: 0.8905 - val_accuracy: 0.7322 - val_IoU: 0.4988
# Epoch 11/100
# 27/27 [==============================] - 26s 978ms/step - loss: 0.9064 - accuracy: 0.7224 - IoU: 0.4934 - val_loss: 1.1871 - val_accuracy: 0.5198 - val_IoU: 0.3937
# Epoch 12/100
# 27/27 [==============================] - 27s 1s/step - loss: 0.9104 - accuracy: 0.6867 - IoU: 0.4786 - val_loss: 0.8955 - val_accuracy: 0.7128 - val_IoU: 0.4944
# Epoch 13/100
# 27/27 [==============================] - 27s 1s/step - loss: 0.8694 - accuracy: 0.7277 - IoU: 0.5088 - val_loss: 1.0246 - val_accuracy: 0.6392 - val_IoU: 0.4738
# Epoch 14/100
# 27/27 [==============================] - 26s 983ms/step - loss: 0.8366 - accuracy: 0.7105 - IoU: 0.5058 - val_loss: 0.9037 - val_accuracy: 0.7018 - val_IoU: 0.4661
# Epoch 15/100
# 27/27 [==============================] - 27s 1s/step - loss: 0.8213 - accuracy: 0.7167 - IoU: 0.5144 - val_loss: 0.8888 - val_accuracy: 0.6956 - val_IoU: 0.4718
# Epoch 16/100
# 27/27 [==============================] - 27s 1s/step - loss: 0.8312 - accuracy: 0.6913 - IoU: 0.5009 - val_loss: 0.7652 - val_accuracy: 0.7675 - val_IoU: 0.5115
# Epoch 17/100
# 27/27 [==============================] - 27s 1s/step - loss: 0.8297 - accuracy: 0.7149 - IoU: 0.5113 - val_loss: 0.7772 - val_accuracy: 0.7629 - val_IoU: 0.5193
# Epoch 18/100
# 27/27 [==============================] - 26s 981ms/step - loss: 0.8058 - accuracy: 0.7323 - IoU: 0.5202 - val_loss: 1.0402 - val_accuracy: 0.6098 - val_IoU: 0.4193
# Epoch 19/100
# 27/27 [==============================] - 27s 1s/step - loss: 0.8398 - accuracy: 0.7102 - IoU: 0.5069 - val_loss: 0.8446 - val_accuracy: 0.7285 - val_IoU: 0.4941
# Epoch 20/100
# 27/27 [==============================] - 26s 981ms/step - loss: 0.7792 - accuracy: 0.7107 - IoU: 0.5197 - val_loss: 0.8519 - val_accuracy: 0.7087 - val_IoU: 0.5027
# Epoch 21/100
# 27/27 [==============================] - 26s 983ms/step - loss: 0.7516 - accuracy: 0.7145 - IoU: 0.5224 - val_loss: 0.8965 - val_accuracy: 0.6905 - val_IoU: 0.4923
# Epoch 22/100
# 27/27 [==============================] - 26s 981ms/step - loss: 0.7545 - accuracy: 0.7156 - IoU: 0.5251 - val_loss: 0.8663 - val_accuracy: 0.6915 - val_IoU: 0.5080
# Epoch 23/100
# 27/27 [==============================] - 27s 1s/step - loss: 0.7479 - accuracy: 0.7100 - IoU: 0.5221 - val_loss: 0.8021 - val_accuracy: 0.7370 - val_IoU: 0.5075
# Epoch 24/100
# 27/27 [==============================] - 27s 1s/step - loss: 0.7556 - accuracy: 0.7487 - IoU: 0.5320 - val_loss: 0.9305 - val_accuracy: 0.6475 - val_IoU: 0.4921
# Epoch 25/100
# 27/27 [==============================] - 27s 1s/step - loss: 0.7619 - accuracy: 0.6931 - IoU: 0.5112 - val_loss: 0.8397 - val_accuracy: 0.7298 - val_IoU: 0.4870
# Epoch 26/100
# 27/27 [==============================] - 27s 1s/step - loss: 0.7772 - accuracy: 0.7088 - IoU: 0.5084 - val_loss: 0.7620 - val_accuracy: 0.7418 - val_IoU: 0.5051
# Epoch 27/100
# 27/27 [==============================] - 27s 1s/step - loss: 0.7655 - accuracy: 0.7326 - IoU: 0.5227 - val_loss: 0.9764 - val_accuracy: 0.6387 - val_IoU: 0.4802
# Epoch 28/100
# 27/27 [==============================] - 27s 1s/step - loss: 0.7858 - accuracy: 0.6929 - IoU: 0.5108 - val_loss: 0.8833 - val_accuracy: 0.6598 - val_IoU: 0.4966
# Epoch 29/100
# 27/27 [==============================] - 26s 977ms/step - loss: 0.7152 - accuracy: 0.7309 - IoU: 0.5349 - val_loss: 0.8730 - val_accuracy: 0.6696 - val_IoU: 0.5030
# Epoch 30/100
# 27/27 [==============================] - 27s 1s/step - loss: 0.6845 - accuracy: 0.7229 - IoU: 0.5360 - val_loss: 0.7499 - val_accuracy: 0.7247 - val_IoU: 0.5258
# Epoch 31/100
# 27/27 [==============================] - 26s 983ms/step - loss: 0.6795 - accuracy: 0.7309 - IoU: 0.5395 - val_loss: 0.8498 - val_accuracy: 0.6791 - val_IoU: 0.5014
# Epoch 32/100
# 27/27 [==============================] - 27s 1s/step - loss: 0.6730 - accuracy: 0.7275 - IoU: 0.5368 - val_loss: 0.9019 - val_accuracy: 0.6432 - val_IoU: 0.4860
# Epoch 33/100
# 27/27 [==============================] - 27s 1s/step - loss: 0.6831 - accuracy: 0.7328 - IoU: 0.5379 - val_loss: 0.9300 - val_accuracy: 0.6471 - val_IoU: 0.4831
# Epoch 34/100
# 27/27 [==============================] - 27s 1s/step - loss: 0.6852 - accuracy: 0.7115 - IoU: 0.5279 - val_loss: 0.7594 - val_accuracy: 0.7356 - val_IoU: 0.5229
# Epoch 35/100
# 27/27 [==============================] - 27s 1s/step - loss: 0.6901 - accuracy: 0.7165 - IoU: 0.5283 - val_loss: 0.8361 - val_accuracy: 0.7056 - val_IoU: 0.4985
# Epoch 36/100
# 27/27 [==============================] - 27s 1s/step - loss: 0.6952 - accuracy: 0.7467 - IoU: 0.5388 - val_loss: 0.8183 - val_accuracy: 0.6852 - val_IoU: 0.5156
# Epoch 37/100
# 27/27 [==============================] - 27s 1s/step - loss: 0.6918 - accuracy: 0.7194 - IoU: 0.5304 - val_loss: 0.9153 - val_accuracy: 0.6320 - val_IoU: 0.4950
# Epoch 38/100
# 27/27 [==============================] - 26s 975ms/step - loss: 0.6533 - accuracy: 0.7430 - IoU: 0.5443 - val_loss: 0.8975 - val_accuracy: 0.6397 - val_IoU: 0.5052
# Epoch 39/100
# 27/27 [==============================] - 27s 1s/step - loss: 0.6895 - accuracy: 0.7132 - IoU: 0.5270 - val_loss: 0.8971 - val_accuracy: 0.6521 - val_IoU: 0.4546
# Epoch 40/100
# 27/27 [==============================] - 27s 1s/step - loss: 0.7721 - accuracy: 0.7493 - IoU: 0.5336 - val_loss: 0.9822 - val_accuracy: 0.6304 - val_IoU: 0.4854
# Epoch 41/100
# 27/27 [==============================] - 27s 999ms/step - loss: 0.6932 - accuracy: 0.7188 - IoU: 0.5313 - val_loss: 0.8647 - val_accuracy: 0.6933 - val_IoU: 0.5010
# Epoch 42/100
# 27/27 [==============================] - 27s 983ms/step - loss: 0.6251 - accuracy: 0.7304 - IoU: 0.5445 - val_loss: 0.6827 - val_accuracy: 0.7682 - val_IoU: 0.5310
# Epoch 43/100
# 27/27 [==============================] - 27s 1s/step - loss: 0.6278 - accuracy: 0.7533 - IoU: 0.5478 - val_loss: 0.7601 - val_accuracy: 0.7397 - val_IoU: 0.5181
# Epoch 44/100
# 27/27 [==============================] - 27s 983ms/step - loss: 0.6091 - accuracy: 0.7472 - IoU: 0.5448 - val_loss: 0.8899 - val_accuracy: 0.6668 - val_IoU: 0.5127
# Epoch 45/100
# 27/27 [==============================] - 27s 1s/step - loss: 0.6417 - accuracy: 0.7238 - IoU: 0.5312 - val_loss: 0.7091 - val_accuracy: 0.7640 - val_IoU: 0.5310
# Epoch 46/100
# 27/27 [==============================] - 27s 986ms/step - loss: 0.5979 - accuracy: 0.7622 - IoU: 0.5545 - val_loss: 0.9291 - val_accuracy: 0.6512 - val_IoU: 0.4935
# Epoch 47/100
# 27/27 [==============================] - 26s 982ms/step - loss: 0.5917 - accuracy: 0.7289 - IoU: 0.5434 - val_loss: 0.7492 - val_accuracy: 0.7261 - val_IoU: 0.5163
# Epoch 48/100
# 27/27 [==============================] - 27s 1s/step - loss: 0.5666 - accuracy: 0.7651 - IoU: 0.5551 - val_loss: 0.8166 - val_accuracy: 0.6996 - val_IoU: 0.5156
# Epoch 49/100
# 27/27 [==============================] - 27s 1s/step - loss: 0.5360 - accuracy: 0.7575 - IoU: 0.5580 - val_loss: 0.8309 - val_accuracy: 0.6929 - val_IoU: 0.5182
# Epoch 50/100
# 27/27 [==============================] - 27s 1s/step - loss: 0.5407 - accuracy: 0.7464 - IoU: 0.5540 - val_loss: 0.7172 - val_accuracy: 0.7409 - val_IoU: 0.5362
# Epoch 51/100
# 27/27 [==============================] - 27s 1s/step - loss: 0.5277 - accuracy: 0.7594 - IoU: 0.5603 - val_loss: 0.7020 - val_accuracy: 0.7623 - val_IoU: 0.5373
# Epoch 52/100
# 27/27 [==============================] - 26s 983ms/step - loss: 0.5767 - accuracy: 0.7663 - IoU: 0.5545 - val_loss: 0.9506 - val_accuracy: 0.6252 - val_IoU: 0.4808
# Epoch 53/100
# 27/27 [==============================] - 27s 986ms/step - loss: 0.5849 - accuracy: 0.7412 - IoU: 0.5492 - val_loss: 0.7807 - val_accuracy: 0.7195 - val_IoU: 0.5175
# Epoch 54/100
# 27/27 [==============================] - 27s 984ms/step - loss: 0.5481 - accuracy: 0.7583 - IoU: 0.5567 - val_loss: 0.7064 - val_accuracy: 0.7330 - val_IoU: 0.5269

# %%
y_hat = best_model.predict(X_test)
y_pred = tf.expand_dims(tf.argmax(y_hat, axis=-1), axis=-1)
# Out:
# 9/9 [==============================] - 5s 615ms/step

# %%
accuracy_score(y_test.reshape(-1), y_pred.numpy().reshape(-1))
# Out:
# 0.8050915363647929

# %%
m_iou = MeanIoU(num_classes=n_classes)
m_iou.update_state(y_test, y_pred)
m_iou.result().numpy()
# Out:
# 0.557599

# %%
visualize_predictions(X_test, y_test, y_pred, random.randint(0,len(y_test)-1))

# %% [markdown]
# ##Model evaluation

# %%
plot_learning_curve(history)

# %%
plot_confusion_matrix(y_test, y_pred, n_classes)
