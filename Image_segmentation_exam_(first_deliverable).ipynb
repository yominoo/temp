# %% [markdown]
# ##Loading and Importing Libraries

# %%
# !pip install tensorflow scikeras matplotlib scikit-learn
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.15.0)
# Requirement already satisfied: scikeras in /usr/local/lib/python3.10/dist-packages (0.12.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.25.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.64.1)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.43.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (1.2.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.0.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (5.4.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2024.7.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow) (2.1.5)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (3.2.2)

# %%
import pandas
import numpy as np
import random
import itertools
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, Conv2DTranspose, MaxPool2D, Concatenate, Input, Lambda, BatchNormalization, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.backend import clear_session
from keras.metrics import MeanIoU
from sklearn.model_selection import train_test_split, learning_curve, GridSearchCV
from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay
from sklearn.utils.class_weight import compute_class_weight

# %% [markdown]
# ##Importing Data

# %%
import urllib.request
import zipfile
# ZIP data URL from GitHub
zip_url = "http://frasca.di.unimi.it/MLDNN/input_data.zip"
# Download the ZIP
zip_path, _ = urllib.request.urlretrieve(zip_url)
# Unzip the folder
target_folder = "temp"
# reading data
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(target_folder)
data_path = f"{target_folder}/input_data.pkl"
#Then use the following lines to read it:
import pickle as pk
with open(data_path, 'rb') as f:
    dd = pk.load(f)

imgs = dd['imgs']
masks = dd['masks']

# %%
imgs.shape, masks.shape
# Out:
# ((1305, 256, 256, 3), (1305, 256, 256, 1))

# %% [markdown]
# Now, I plot some random images with their relative mask to get to understand the context of the task

# %%
def plot_img(idx):
  fig, axs = plt.subplots(1, 2)
  axs[0].imshow(imgs[idx])
  axs[1].imshow(masks[idx])

# %%
idx = random.randint(0, imgs.shape[0]-1)
plot_img(idx)

# %% [markdown]
# So, the images are urban images and the goal is to locate different elements of the urban environment

# %% [markdown]
# ##Data Preprocessing

# %% [markdown]
# Values of the images pixels

# %%
imgs.max(), imgs.min()
# Out:
# (255, 0)

# %% [markdown]
# Values of the masks pixels

# %%
masks.max(), masks.min()
# Out:
# (5, 0)

# %% [markdown]
# Rescale images values in the [0,1] interval

# %%
imgs.dtype
# Out:
# dtype('uint8')

# %%
imgs = imgs.astype('float64')

# %%
imgs /= 255
imgs.max(), imgs.min()
# Out:
# (1.0, 0.0)

# %%
plot_img(random.randint(0,imgs.shape[0]-1))

# %%
img_shape = (imgs.shape[1], imgs.shape[2], imgs.shape[3])

# %%
n_classes = len(np.unique(masks))

# %% [markdown]
# ##Classes balance

# %%
unique, counts = np.unique(masks, return_counts=True)
print(np.asarray((unique, counts)).T)
# Out:
# [[       0 11698953]
#  [       1 45571963]
#  [       2  7985171]
#  [       3  8743823]
#  [       4 11116730]
#  [       5   407840]]

# %% [markdown]
# Class 5 is heavily under represented while class 1 is over represented, so I will adjust class weights in the loss function accordingly

# %%
class_weights = compute_class_weight('balanced', classes=np.unique(masks), y=masks.reshape(-1))
class_weights
# Out:
# array([ 1.21840647,  0.31278179,  1.78506885,  1.63018853,  1.28221878,
#        34.95017654])

# %%
class_weights = {i:weight for i, weight in enumerate(class_weights) }
class_weights
# Out:
# {0: 1.2184064676556954,
#  1: 0.31278178646814053,
#  2: 1.785068848243826,
#  3: 1.6301885342372553,
#  4: 1.282218781961962,
#  5: 34.95017653981954}

# %% [markdown]
# ##Train-Test Splitting

# %%
X_train, X_test, y_train, y_test = train_test_split(imgs, masks, test_size=.2)

# %%
print(X_train.shape, X_test.shape)
print(y_train.shape, y_test.shape)
# Out:
# (1044, 256, 256, 3) (261, 256, 256, 3)
# (1044, 256, 256, 1) (261, 256, 256, 1)

# %% [markdown]
# ##Custom Utility Functions and Classes

# %% [markdown]
# Custom Intersection over Union in order to use it also as training metric

# %%
class CustomMeanIoU(tf.keras.metrics.MeanIoU):
    def __init__(self, num_classes=None, name=None, dtype=None):
        super(CustomMeanIoU, self).__init__(
            num_classes=num_classes, name=name, dtype=dtype
        )

    def update_state(self, y_true, y_pred, sample_weight=None):
        y_pred = tf.math.argmax(y_pred, axis=-1)
        return super().update_state(y_true, y_pred, sample_weight)

# %% [markdown]
# General function to get class weights to train the model given the labels

# %%
def get_class_weights(y):
  class_weights = compute_class_weight('balanced', classes=np.unique(y), y=y.reshape(-1))
  class_weights = {i:weight for i, weight in enumerate(class_weights) }

  return class_weights

# %% [markdown]
# Function to evaluate accuracy and Intersection over Union of a model on a validation set

# %%
def evaluate_model(model, X_tra, y_tra, X_val, y_val, class_weights, batch_size, epochs):
  model.fit(X_tra, y_tra, batch_size=batch_size, epochs=epochs, class_weight=class_weights, validation_data=(X_val, y_val))
  val_loss, val_acc, val_iou = model.evaluate(X_val, y_val, batch_size=batch_size, verbose=0)

  clear_session()

  return val_loss, val_acc, val_iou

# %% [markdown]
# Function to visualize real imagem real label, predicted label

# %%
def visualize_predictions(X_true, y_true, y_pred, idx):
    fig, axs = plt.subplots(1, 3)
    axs[0].imshow(X_true[idx])
    axs[0].set_title("Image")
    axs[1].imshow(y_true[idx])
    axs[1].set_title("Ground Truth")
    axs[2].imshow(y_pred[idx])
    axs[2].set_title("Prediction")
    plt.show()

# %% [markdown]
# Functions to plot the learning curve of a model and its confusion matrix

# %%
def plot_learning_curve(history):
  plt.figure(figsize=(12, 4))

  # Plot training and validation loss
  plt.subplot(1, 2, 1)
  plt.plot(history.history['loss'], label='Training Loss')
  plt.plot(history.history['val_loss'], label='Validation Loss')
  plt.title('Model Loss')
  plt.xlabel('Epoch')
  plt.ylabel('Loss')
  plt.legend()

  # Plot training and validation accuracy
  plt.subplot(1, 2, 2)
  plt.plot(history.history['accuracy'], label='Training Accuracy')
  plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
  plt.title('Model Accuracy')
  plt.xlabel('Epoch')
  plt.ylabel('Accuracy')
  plt.legend()

  plt.show()

# %%
def plot_confusion_matrix(y_true, y_pred, num_classes):
  # Compute the confusion matrix
  cm = confusion_matrix(y_test.reshape(-1), y_pred.numpy().reshape(-1))

  # Plot the confusion matrix
  disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=[f'Class {i}' for i in range(num_classes)])
  disp.plot(cmap=plt.cm.Blues)
  plt.title('Confusion Matrix')
  plt.show()

# %% [markdown]
# ##Model Architecture
# I'm using a Fully Convolutional Neural Network to solve the task, having both as input and as output images. So I have to build the structure of the encoder and that of the decoder, connecting them through a bottleneck. For this scope I will only include in the network layers of the following kinds: Conv2d, MaxPool2d, Conv2dTranspose and Concatenate layers to include the skip connections in the network.
# I will firstly define a convolutional block and an transpose convolutional block which I will use as main components respectively of the encoder and of the decoder; in this way it will be easier to scale up the model if needed

# %%
# CONVOLUTIONAL BLOCK
# I'm assuming that the blocks have a fixed number of layers (2 Conv2D, 1 MaxPool2D)
# and that all the layers in the block have the same number of filters (n_filters)
# Dropout and BatchNormalization layer because they are possible ways to get a better model but I did not mention them in the written part of the exam

def convolutional_block(x, n_filters:int, kernel_size:tuple[int]=(3, 3), padding:str="same", pool_size:tuple[int]=(2,2)):
  conv = Conv2D(n_filters, kernel_size=kernel_size, padding=padding, activation='relu', kernel_initializer='he_normal')(x)
  #conv = Dropout(.3)(conv)
  conv = Conv2D(n_filters, kernel_size=kernel_size, padding=padding, activation='relu', kernel_initializer='he_normal')(conv)
  #conv = BatchNormalization()(conv, training=False)

  pool = MaxPool2D(pool_size=pool_size)(conv)

  return conv, pool

# TRANSPOSE CONVOLUTIONAL BLOCK
# I'm assuming that the blocks have a fixed number of layers (1 Conv2DTranspose, 2 Conv2D + skip connection)
# and that all the Conv2D layers in the block have the same number of filters (n_filters_conv);

def transpose_block(x, skip, n_filters:int, kernel_size:tuple[int]=(3, 3), padding:str="same", stride_trans:tuple[int]=(2,2)):
  trans_conv = Conv2DTranspose(n_filters, kernel_size=(2,2), strides=stride_trans, padding=padding)(x)
  conc = Concatenate()([skip, trans_conv])
  conv = Conv2D(n_filters, kernel_size=kernel_size, padding=padding, activation='relu', kernel_initializer='he_normal')(conc)
  #conv = Dropout(.3)(conv)
  conv = Conv2D(n_filters, kernel_size=kernel_size, padding=padding, activation='relu', kernel_initializer='he_normal')(conv)

  return conv

# %%
def FCNN(img_shape:tuple[int], n_classes:int, n_filters_list:list[int], \
         kernel_size:tuple[int]=(3, 3), padding:str="same", pool_size:tuple[int]=(2,2)):
  input = Input(shape=img_shape)
  conv_layers = []
  pool_layers = []
  decoder_layers = []

  # ENCODER
  for i, n_filters in enumerate(n_filters_list):
    if i == 0:
      conv, pool = convolutional_block(input, n_filters, kernel_size, padding, pool_size)
      conv_layers.append(conv)
      pool_layers.append(pool)
    else:
      conv, pool = convolutional_block(pool_layers[-1], n_filters, kernel_size, padding, pool_size)
      conv_layers.append(conv)
      pool_layers.append(pool)

  # BOTTLENECK
  # I'm assuming a fixed size bottleneck with 2 layers
  # with the same number of filters of the last encoding block (or first decoding block)
  bot = Conv2D(n_filters_list[-1], kernel_size=kernel_size, padding=padding, activation='relu', kernel_initializer='he_normal')(pool_layers[-1])
  bot = Conv2D(n_filters_list[-1], kernel_size=kernel_size, padding=padding, activation='relu', kernel_initializer='he_normal')(bot)

  # DECODER
  for i, n_filters in enumerate(n_filters_list):
    if i == 0:
      conv = transpose_block(bot, conv_layers[-(i+1)], n_filters_list[-(i+1)], kernel_size, padding)
      decoder_layers.append(conv)
    else:
      conv = transpose_block(decoder_layers[-1], conv_layers[-(i+1)], n_filters_list[-(i+1)], kernel_size, padding)
      decoder_layers.append(conv)

  # OUTPUT layers
  output = Conv2D(n_classes, kernel_size=(1,1), padding=padding, activation='softmax')(decoder_layers[-1])

  model = Model(inputs=[input], outputs=[output])
  model.compile(optimizer='Adam', loss='sparse_categorical_crossentropy', metrics=['accuracy', CustomMeanIoU(num_classes=n_classes, name='IoU')])
  return model

# %% [markdown]
# ##Base Model
# Now I train a base model and evaluate his performance to keep it as term of comparison later in the work. In this stage I'm not trying to optimize any parameter.

# %%
n_filters_list = [16, 32, 64]
model = FCNN(img_shape=img_shape,
             n_classes=n_classes,
             n_filters_list=n_filters_list)

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  conv2d (Conv2D)             (None, 256, 256, 16)         448       ['input_1[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 256, 256, 16)         2320      ['conv2d[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 128, 128, 16)         0         ['conv2d_1[0][0]']
#  D)
#
#  conv2d_2 (Conv2D)           (None, 128, 128, 32)         4640      ['max_pooling2d[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 128, 128, 32)         9248      ['conv2d_2[0][0]']
#
#  max_pooling2d_1 (MaxPoolin  (None, 64, 64, 32)           0         ['conv2d_3[0][0]']
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 64, 64, 64)           18496     ['max_pooling2d_1[0][0]']
#
#  conv2d_5 (Conv2D)           (None, 64, 64, 64)           36928     ['conv2d_4[0][0]']
#
#  max_pooling2d_2 (MaxPoolin  (None, 32, 32, 64)           0         ['conv2d_5[0][0]']
#  g2D)
#
#  conv2d_6 (Conv2D)           (None, 32, 32, 64)           36928     ['max_pooling2d_2[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 32, 32, 64)           36928     ['conv2d_6[0][0]']
#
#  conv2d_transpose (Conv2DTr  (None, 64, 64, 64)           16448     ['conv2d_7[0][0]']
#  anspose)
#
#  concatenate (Concatenate)   (None, 64, 64, 128)          0         ['conv2d_5[0][0]',
#                                                                      'conv2d_transpose[0][0]']
#
#  conv2d_8 (Conv2D)           (None, 64, 64, 64)           73792     ['concatenate[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 64, 64, 64)           36928     ['conv2d_8[0][0]']
#
#  conv2d_transpose_1 (Conv2D  (None, 128, 128, 32)         8224      ['conv2d_9[0][0]']
#  Transpose)
#
#  concatenate_1 (Concatenate  (None, 128, 128, 64)         0         ['conv2d_3[0][0]',
#  )                                                                   'conv2d_transpose_1[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 128, 128, 32)         18464     ['concatenate_1[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 128, 128, 32)         9248      ['conv2d_10[0][0]']
#
#  conv2d_transpose_2 (Conv2D  (None, 256, 256, 16)         2064      ['conv2d_11[0][0]']
#  Transpose)
#
#  concatenate_2 (Concatenate  (None, 256, 256, 32)         0         ['conv2d_1[0][0]',
#  )                                                                   'conv2d_transpose_2[0][0]']
#
#  conv2d_12 (Conv2D)          (None, 256, 256, 16)         4624      ['concatenate_2[0][0]']
#
#  conv2d_13 (Conv2D)          (None, 256, 256, 16)         2320      ['conv2d_12[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 256, 256, 6)          102       ['conv2d_13[0][0]']
#
# ==================================================================================================
# Total params: 318150 (1.21 MB)
# Trainable params: 318150 (1.21 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
model.fit(X_train, y_train, batch_size=32, epochs=10, class_weight=class_weights)
# Out:
# Epoch 1/10
# 33/33 [==============================] - 36s 487ms/step - loss: 1.6954 - accuracy: 0.4790 - IoU: 0.1670
# Epoch 2/10
# 33/33 [==============================] - 9s 267ms/step - loss: 1.4305 - accuracy: 0.5985 - IoU: 0.3264
# Epoch 3/10
# 33/33 [==============================] - 9s 264ms/step - loss: 1.2536 - accuracy: 0.6277 - IoU: 0.3723
# Epoch 4/10
# 33/33 [==============================] - 9s 261ms/step - loss: 1.1768 - accuracy: 0.6649 - IoU: 0.3908
# Epoch 5/10
# 33/33 [==============================] - 9s 258ms/step - loss: 1.1354 - accuracy: 0.6456 - IoU: 0.4081
# Epoch 6/10
# 33/33 [==============================] - 9s 259ms/step - loss: 1.0969 - accuracy: 0.6328 - IoU: 0.4067
# Epoch 7/10
# 33/33 [==============================] - 9s 265ms/step - loss: 1.0616 - accuracy: 0.6603 - IoU: 0.4361
# Epoch 8/10
# 33/33 [==============================] - 9s 264ms/step - loss: 1.0729 - accuracy: 0.6921 - IoU: 0.4466
# Epoch 9/10
# 33/33 [==============================] - 9s 258ms/step - loss: 1.0243 - accuracy: 0.6815 - IoU: 0.4630
# Epoch 10/10
# 33/33 [==============================] - 9s 262ms/step - loss: 0.9747 - accuracy: 0.6879 - IoU: 0.4760

# %%
y_hat = model.predict(X_test)
y_pred = tf.expand_dims(tf.argmax(y_hat, axis=-1), axis=-1)
# Out:
# 9/9 [==============================] - 2s 181ms/step

# %%
print(accuracy_score(y_test.reshape(-1), y_pred.numpy().reshape(-1)))
m_iou = CustomMeanIoU(num_classes=n_classes)
m_iou.update_state(y_test, y_hat)
print(m_iou.result().numpy())
# Out:
# 0.711431919843301
# 0.46632215

# %% [markdown]
# ##Hyperparameter Tuning
# While I'm displaying both accuracy and Intersection over Union as performance metrics \\
# **I will only consider accuracy since I did not mention Intersection over Union in the written part of the exam** \\
# It would be preferable, though, due to the semantic segmentation nature of the task, to take Intersection over Union in consideration as main metric

# %%
param_grid = {
    'n_filters_list' : [[32, 64], [64, 128], [16, 32, 64], [32, 64, 128], [16, 32, 64, 128]],
    'batch_size' : [8, 16, 32]
}

# %% [markdown]
# I'm writing a custom grid_search since the scikit_learn implementation is not optimal for handling image kind of data, in particular the wrappers (KerasClassifier) may not work correctly for this sake

# %%
def grid_search(model_func, img_shape, n_classes, param_grid, X, y, epochs, val_size=.2, random_state=42):
  # Generate all combinations of parameters
  param_combinations = list(itertools.product(*param_grid.values()))
  print(f'Searching in {len(param_combinations)} combinations')

  best_score = 0
  best_params = None
  best_model = None

  X_tra, X_val, y_tra, y_val = train_test_split(X, y, test_size=val_size, shuffle=True,random_state=random_state)
  class_weights = get_class_weights(y_tra)

  for idx, params in enumerate(param_combinations):
    current_params = dict(zip(param_grid.keys(), params))
    print(f'Configuration {idx+1}/{len(param_combinations)} -> current parameters: ', current_params)
    batch_size = current_params.pop('batch_size')
    model = model_func(img_shape=img_shape, n_classes=n_classes,
                  n_filters_list=current_params['n_filters_list'])

    # Evaluating the current model
    print('Evaluating...')
    val_loss, val_acc, val_iou = evaluate_model(model, X_tra, y_tra, X_val, y_val, class_weights, batch_size, epochs)
    print(f'Validation accuracy: {val_acc}, Validation IoU: {val_iou}')

    # Here I'm only considering accuracy to select the best model
    if val_acc > best_score:
      best_score = val_acc
      best_params = {**current_params, 'batch_size': batch_size}
      best_model = model

  print("Best Score:", best_score)
  print("Best Params:", best_params)
  return best_model, best_params, best_score

# %%
# Partial datasets to be de-commented in case of hardware constraints
partial_X_train = X_train[:400]
partial_y_train = y_train[:400]

best_model, best_params, best_score = grid_search(model_func=FCNN,
                                                  img_shape=img_shape,
                                                  n_classes=n_classes,
                                                  param_grid=param_grid,
                                                  X=partial_X_train,
                                                  y=partial_y_train,
                                                  epochs=6)
# Out:
# Searching in 15 combinations
# Configuration 1/15 -> current parameters:  {'n_filters_list': [32, 64], 'batch_size': 8}
# Evaluating...
# Epoch 1/6
# 40/40 [==============================] - 15s 132ms/step - loss: 1.6945 - accuracy: 0.3771 - IoU: 0.1178 - val_loss: 1.4004 - val_accuracy: 0.5648 - val_IoU: 0.2021
# Epoch 2/6
# 40/40 [==============================] - 4s 112ms/step - loss: 1.5691 - accuracy: 0.4670 - IoU: 0.2327 - val_loss: 1.1195 - val_accuracy: 0.6694 - val_IoU: 0.3056
# Epoch 3/6
# 40/40 [==============================] - 4s 111ms/step - loss: 1.2622 - accuracy: 0.6483 - IoU: 0.3575 - val_loss: 1.0860 - val_accuracy: 0.6746 - val_IoU: 0.3403
# Epoch 4/6
# 40/40 [==============================] - 4s 110ms/step - loss: 1.1671 - accuracy: 0.6518 - IoU: 0.3969 - val_loss: 1.0719 - val_accuracy: 0.6883 - val_IoU: 0.4116
# Epoch 5/6
# 40/40 [==============================] - 5s 121ms/step - loss: 1.0954 - accuracy: 0.5838 - IoU: 0.3954 - val_loss: 0.9726 - val_accuracy: 0.7350 - val_IoU: 0.4502
# Epoch 6/6
# 40/40 [==============================] - 4s 110ms/step - loss: 1.1155 - accuracy: 0.7261 - IoU: 0.4411 - val_loss: 0.9843 - val_accuracy: 0.7292 - val_IoU: 0.4521
# Validation accuracy: 0.7291942834854126, Validation IoU: 0.45208701491355896
# Configuration 2/15 -> current parameters:  {'n_filters_list': [32, 64], 'batch_size': 16}
# Evaluating...
# Epoch 1/6
# 20/20 [==============================] - 19s 269ms/step - loss: 1.7391 - accuracy: 0.4789 - IoU: 0.1351 - val_loss: 1.3963 - val_accuracy: 0.5243 - val_IoU: 0.1599
# Epoch 2/6
# 20/20 [==============================] - 4s 221ms/step - loss: 1.6326 - accuracy: 0.5337 - IoU: 0.1903 - val_loss: 1.2887 - val_accuracy: 0.6035 - val_IoU: 0.2257
# Epoch 3/6
# 20/20 [==============================] - 5s 229ms/step - loss: 1.4395 - accuracy: 0.4226 - IoU: 0.2484 - val_loss: 1.0857 - val_accuracy: 0.6802 - val_IoU: 0.3590
# Epoch 4/6
# 20/20 [==============================] - 4s 222ms/step - loss: 1.2324 - accuracy: 0.6841 - IoU: 0.3799 - val_loss: 1.5607 - val_accuracy: 0.5363 - val_IoU: 0.2526
# Epoch 5/6
# 20/20 [==============================] - 5s 238ms/step - loss: 1.1631 - accuracy: 0.6006 - IoU: 0.3823 - val_loss: 1.0313 - val_accuracy: 0.7159 - val_IoU: 0.4119
# Epoch 6/6
# 20/20 [==============================] - 4s 223ms/step - loss: 1.0899 - accuracy: 0.6104 - IoU: 0.4091 - val_loss: 0.9937 - val_accuracy: 0.7369 - val_IoU: 0.4324
# Validation accuracy: 0.7368665933609009, Validation IoU: 0.43241551518440247
# Configuration 3/15 -> current parameters:  {'n_filters_list': [32, 64], 'batch_size': 32}
# Evaluating...
# Epoch 1/6
# 10/10 [==============================] - 25s 602ms/step - loss: 1.7764 - accuracy: 0.3044 - IoU: 0.0883 - val_loss: 1.7354 - val_accuracy: 0.0880 - val_IoU: 0.0276
# Epoch 2/6
# 10/10 [==============================] - 4s 443ms/step - loss: 1.6969 - accuracy: 0.1761 - IoU: 0.0645 - val_loss: 1.5016 - val_accuracy: 0.5454 - val_IoU: 0.1634
# Epoch 3/6
# 10/10 [==============================] - 5s 468ms/step - loss: 1.6091 - accuracy: 0.5796 - IoU: 0.2195 - val_loss: 1.3680 - val_accuracy: 0.5410 - val_IoU: 0.2480
# Epoch 4/6
# 10/10 [==============================] - 4s 446ms/step - loss: 1.4253 - accuracy: 0.5542 - IoU: 0.2775 - val_loss: 1.3245 - val_accuracy: 0.5876 - val_IoU: 0.2846
# Epoch 5/6
# 10/10 [==============================] - 4s 447ms/step - loss: 1.3257 - accuracy: 0.6424 - IoU: 0.3439 - val_loss: 1.2670 - val_accuracy: 0.5893 - val_IoU: 0.3126
# Epoch 6/6
# 10/10 [==============================] - 5s 459ms/step - loss: 1.2168 - accuracy: 0.5711 - IoU: 0.3497 - val_loss: 1.1058 - val_accuracy: 0.6873 - val_IoU: 0.3780
# Validation accuracy: 0.6872989535331726, Validation IoU: 0.3780178725719452
# Configuration 4/15 -> current parameters:  {'n_filters_list': [64, 128], 'batch_size': 8}
# Evaluating...
# Epoch 1/6
# 40/40 [==============================] - 25s 285ms/step - loss: 1.6990 - accuracy: 0.3789 - IoU: 0.1351 - val_loss: 1.5355 - val_accuracy: 0.0870 - val_IoU: 0.1259
# Epoch 2/6
# 40/40 [==============================] - 10s 255ms/step - loss: 1.4890 - accuracy: 0.4365 - IoU: 0.2447 - val_loss: 1.1932 - val_accuracy: 0.6546 - val_IoU: 0.3336
# Epoch 3/6
# 40/40 [==============================] - 11s 266ms/step - loss: 1.3038 - accuracy: 0.5846 - IoU: 0.3416 - val_loss: 1.2650 - val_accuracy: 0.5213 - val_IoU: 0.3437
# Epoch 4/6
# 40/40 [==============================] - 10s 252ms/step - loss: 1.2348 - accuracy: 0.4884 - IoU: 0.3342 - val_loss: 1.0104 - val_accuracy: 0.7001 - val_IoU: 0.3965
# Epoch 5/6
# 40/40 [==============================] - 11s 268ms/step - loss: 1.1847 - accuracy: 0.6713 - IoU: 0.4082 - val_loss: 1.0224 - val_accuracy: 0.6943 - val_IoU: 0.4301
# Epoch 6/6
# 40/40 [==============================] - 11s 267ms/step - loss: 1.1221 - accuracy: 0.6038 - IoU: 0.4030 - val_loss: 1.1328 - val_accuracy: 0.6437 - val_IoU: 0.4138
# Validation accuracy: 0.6436546444892883, Validation IoU: 0.41384461522102356
# Configuration 5/15 -> current parameters:  {'n_filters_list': [64, 128], 'batch_size': 16}
# Evaluating...
# Epoch 1/6
# 20/20 [==============================] - 31s 537ms/step - loss: 2.2293 - accuracy: 0.4129 - IoU: 0.1195 - val_loss: 1.2866 - val_accuracy: 0.5605 - val_IoU: 0.1622
# Epoch 2/6
# 20/20 [==============================] - 10s 504ms/step - loss: 1.6623 - accuracy: 0.3944 - IoU: 0.2043 - val_loss: 1.3214 - val_accuracy: 0.6789 - val_IoU: 0.3520
# Epoch 3/6
# 20/20 [==============================] - 10s 504ms/step - loss: 1.4549 - accuracy: 0.6117 - IoU: 0.3160 - val_loss: 1.3617 - val_accuracy: 0.5235 - val_IoU: 0.3468
# Epoch 4/6
# 20/20 [==============================] - 10s 501ms/step - loss: 1.2224 - accuracy: 0.6689 - IoU: 0.3897 - val_loss: 1.1156 - val_accuracy: 0.7013 - val_IoU: 0.4058
# Epoch 5/6
# 20/20 [==============================] - 10s 499ms/step - loss: 1.1217 - accuracy: 0.6426 - IoU: 0.4128 - val_loss: 1.0501 - val_accuracy: 0.7061 - val_IoU: 0.4426
# Epoch 6/6
# 20/20 [==============================] - 9s 465ms/step - loss: 1.1206 - accuracy: 0.6676 - IoU: 0.4188 - val_loss: 1.1351 - val_accuracy: 0.6898 - val_IoU: 0.4011
# Validation accuracy: 0.689763069152832, Validation IoU: 0.4011225402355194
# Configuration 6/15 -> current parameters:  {'n_filters_list': [64, 128], 'batch_size': 32}
# Evaluating...
# Epoch 1/6
# 10/10 [==============================] - 45s 1s/step - loss: 1.7612 - accuracy: 0.2608 - IoU: 0.0942 - val_loss: 1.4885 - val_accuracy: 0.4895 - val_IoU: 0.1459
# Epoch 2/6
# 10/10 [==============================] - 10s 1s/step - loss: 1.5691 - accuracy: 0.5811 - IoU: 0.2204 - val_loss: 1.2238 - val_accuracy: 0.6388 - val_IoU: 0.2786
# Epoch 3/6
# 10/10 [==============================] - 9s 945ms/step - loss: 1.5165 - accuracy: 0.6522 - IoU: 0.3018 - val_loss: 1.3122 - val_accuracy: 0.5871 - val_IoU: 0.2648
# Epoch 4/6
# 10/10 [==============================] - 10s 1s/step - loss: 1.2962 - accuracy: 0.5864 - IoU: 0.3000 - val_loss: 1.2392 - val_accuracy: 0.5497 - val_IoU: 0.3148
# Epoch 5/6
# 10/10 [==============================] - 10s 1s/step - loss: 1.3341 - accuracy: 0.4963 - IoU: 0.3001 - val_loss: 1.2617 - val_accuracy: 0.6146 - val_IoU: 0.2782
# Epoch 6/6
# 10/10 [==============================] - 10s 1s/step - loss: 1.2249 - accuracy: 0.7036 - IoU: 0.3769 - val_loss: 1.1518 - val_accuracy: 0.6799 - val_IoU: 0.3740
# Validation accuracy: 0.6798778772354126, Validation IoU: 0.37398454546928406
# Configuration 7/15 -> current parameters:  {'n_filters_list': [16, 32, 64], 'batch_size': 8}
# Evaluating...
# Epoch 1/6
# 40/40 [==============================] - 14s 97ms/step - loss: 1.7352 - accuracy: 0.4640 - IoU: 0.1448 - val_loss: 1.4744 - val_accuracy: 0.5824 - val_IoU: 0.2758
# Epoch 2/6
# 40/40 [==============================] - 3s 76ms/step - loss: 1.5452 - accuracy: 0.6466 - IoU: 0.3020 - val_loss: 1.1674 - val_accuracy: 0.6528 - val_IoU: 0.2942
# Epoch 3/6
# 40/40 [==============================] - 3s 73ms/step - loss: 1.2761 - accuracy: 0.4915 - IoU: 0.3110 - val_loss: 1.1067 - val_accuracy: 0.7084 - val_IoU: 0.4141
# Epoch 4/6
# 40/40 [==============================] - 3s 75ms/step - loss: 1.2538 - accuracy: 0.6679 - IoU: 0.3802 - val_loss: 1.1285 - val_accuracy: 0.6881 - val_IoU: 0.3861
# Epoch 5/6
# 40/40 [==============================] - 3s 74ms/step - loss: 1.1793 - accuracy: 0.7012 - IoU: 0.4097 - val_loss: 1.0812 - val_accuracy: 0.6747 - val_IoU: 0.4135
# Epoch 6/6
# 40/40 [==============================] - 3s 80ms/step - loss: 1.1576 - accuracy: 0.4916 - IoU: 0.3570 - val_loss: 1.2161 - val_accuracy: 0.2774 - val_IoU: 0.2943
# Validation accuracy: 0.2774019241333008, Validation IoU: 0.29426297545433044
# Configuration 8/15 -> current parameters:  {'n_filters_list': [16, 32, 64], 'batch_size': 16}
# Evaluating...
# Epoch 1/6
# 20/20 [==============================] - 15s 177ms/step - loss: 1.7536 - accuracy: 0.5078 - IoU: 0.1183 - val_loss: 1.4699 - val_accuracy: 0.5213 - val_IoU: 0.1440
# Epoch 2/6
# 20/20 [==============================] - 3s 157ms/step - loss: 1.6286 - accuracy: 0.6004 - IoU: 0.2159 - val_loss: 1.2453 - val_accuracy: 0.6334 - val_IoU: 0.2658
# Epoch 3/6
# 20/20 [==============================] - 3s 147ms/step - loss: 1.5500 - accuracy: 0.5991 - IoU: 0.2571 - val_loss: 1.2582 - val_accuracy: 0.5643 - val_IoU: 0.1836
# Epoch 4/6
# 20/20 [==============================] - 3s 147ms/step - loss: 1.4075 - accuracy: 0.6101 - IoU: 0.2828 - val_loss: 1.3033 - val_accuracy: 0.5938 - val_IoU: 0.2897
# Epoch 5/6
# 20/20 [==============================] - 3s 148ms/step - loss: 1.3150 - accuracy: 0.6455 - IoU: 0.3273 - val_loss: 1.1703 - val_accuracy: 0.6280 - val_IoU: 0.3222
# Epoch 6/6
# 20/20 [==============================] - 3s 147ms/step - loss: 1.2892 - accuracy: 0.6383 - IoU: 0.3489 - val_loss: 1.1796 - val_accuracy: 0.6727 - val_IoU: 0.3884
# Validation accuracy: 0.6727317571640015, Validation IoU: 0.3883955478668213
# Configuration 9/15 -> current parameters:  {'n_filters_list': [16, 32, 64], 'batch_size': 32}
# Evaluating...
# Epoch 1/6
# 10/10 [==============================] - 9s 415ms/step - loss: 1.7720 - accuracy: 0.1976 - IoU: 0.0710 - val_loss: 1.6979 - val_accuracy: 0.1530 - val_IoU: 0.0638
# Epoch 2/6
# 10/10 [==============================] - 3s 284ms/step - loss: 1.6906 - accuracy: 0.2432 - IoU: 0.0770 - val_loss: 1.5660 - val_accuracy: 0.4198 - val_IoU: 0.1357
# Epoch 3/6
# 10/10 [==============================] - 3s 288ms/step - loss: 1.6306 - accuracy: 0.5260 - IoU: 0.1671 - val_loss: 1.4310 - val_accuracy: 0.5950 - val_IoU: 0.1916
# Epoch 4/6
# 10/10 [==============================] - 3s 294ms/step - loss: 1.5909 - accuracy: 0.5688 - IoU: 0.1869 - val_loss: 1.2853 - val_accuracy: 0.5994 - val_IoU: 0.2067
# Epoch 5/6
# 10/10 [==============================] - 3s 311ms/step - loss: 1.5665 - accuracy: 0.5660 - IoU: 0.1962 - val_loss: 1.2673 - val_accuracy: 0.5690 - val_IoU: 0.2036
# Epoch 6/6
# 10/10 [==============================] - 3s 307ms/step - loss: 1.5002 - accuracy: 0.5157 - IoU: 0.2025 - val_loss: 1.2147 - val_accuracy: 0.6069 - val_IoU: 0.2579
# Validation accuracy: 0.6069192886352539, Validation IoU: 0.2579045295715332
# Configuration 10/15 -> current parameters:  {'n_filters_list': [32, 64, 128], 'batch_size': 8}
# Evaluating...
# Epoch 1/6
# 40/40 [==============================] - 13s 161ms/step - loss: 1.7434 - accuracy: 0.4815 - IoU: 0.1572 - val_loss: 1.5558 - val_accuracy: 0.0848 - val_IoU: 0.1215
# Epoch 2/6
# 40/40 [==============================] - 6s 141ms/step - loss: 1.5245 - accuracy: 0.3737 - IoU: 0.2164 - val_loss: 1.4056 - val_accuracy: 0.1775 - val_IoU: 0.2011
# Epoch 3/6
# 40/40 [==============================] - 6s 142ms/step - loss: 1.2789 - accuracy: 0.5166 - IoU: 0.3261 - val_loss: 1.2863 - val_accuracy: 0.6411 - val_IoU: 0.3575
# Epoch 4/6
# 40/40 [==============================] - 5s 137ms/step - loss: 1.1978 - accuracy: 0.6184 - IoU: 0.3779 - val_loss: 1.1153 - val_accuracy: 0.6827 - val_IoU: 0.3501
# Epoch 5/6
# 40/40 [==============================] - 6s 141ms/step - loss: 1.2026 - accuracy: 0.5560 - IoU: 0.3668 - val_loss: 1.0114 - val_accuracy: 0.7245 - val_IoU: 0.4286
# Epoch 6/6
# 40/40 [==============================] - 6s 143ms/step - loss: 1.1547 - accuracy: 0.6574 - IoU: 0.4071 - val_loss: 1.0738 - val_accuracy: 0.7041 - val_IoU: 0.3994
# Validation accuracy: 0.7041028738021851, Validation IoU: 0.39935755729675293
# Configuration 11/15 -> current parameters:  {'n_filters_list': [32, 64, 128], 'batch_size': 16}
# Evaluating...
# Epoch 1/6
# 20/20 [==============================] - 14s 310ms/step - loss: 1.7288 - accuracy: 0.1892 - IoU: 0.0728 - val_loss: 1.5192 - val_accuracy: 0.4619 - val_IoU: 0.1519
# Epoch 2/6
# 20/20 [==============================] - 6s 285ms/step - loss: 1.5374 - accuracy: 0.5967 - IoU: 0.2438 - val_loss: 1.2367 - val_accuracy: 0.6363 - val_IoU: 0.2743
# Epoch 3/6
# 20/20 [==============================] - 6s 304ms/step - loss: 1.3024 - accuracy: 0.6499 - IoU: 0.3618 - val_loss: 1.3089 - val_accuracy: 0.4258 - val_IoU: 0.3052
# Epoch 4/6
# 20/20 [==============================] - 5s 265ms/step - loss: 1.2394 - accuracy: 0.6380 - IoU: 0.3834 - val_loss: 1.3169 - val_accuracy: 0.5390 - val_IoU: 0.3204
# Epoch 5/6
# 20/20 [==============================] - 6s 281ms/step - loss: 1.1549 - accuracy: 0.5775 - IoU: 0.3806 - val_loss: 1.0542 - val_accuracy: 0.6953 - val_IoU: 0.4196
# Epoch 6/6
# 20/20 [==============================] - 5s 275ms/step - loss: 1.1940 - accuracy: 0.6354 - IoU: 0.4001 - val_loss: 1.3340 - val_accuracy: 0.4819 - val_IoU: 0.3091
# Validation accuracy: 0.48190975189208984, Validation IoU: 0.3090564012527466
# Configuration 12/15 -> current parameters:  {'n_filters_list': [32, 64, 128], 'batch_size': 32}
# Evaluating...
# Epoch 1/6
# 10/10 [==============================] - 16s 653ms/step - loss: 1.7659 - accuracy: 0.3780 - IoU: 0.1096 - val_loss: 1.4891 - val_accuracy: 0.5653 - val_IoU: 0.1568
# Epoch 2/6
# 10/10 [==============================] - 5s 558ms/step - loss: 1.6452 - accuracy: 0.5106 - IoU: 0.1501 - val_loss: 1.7413 - val_accuracy: 0.1344 - val_IoU: 0.0602
# Epoch 3/6
# 10/10 [==============================] - 6s 566ms/step - loss: 1.5765 - accuracy: 0.4680 - IoU: 0.1560 - val_loss: 1.2373 - val_accuracy: 0.6259 - val_IoU: 0.2786
# Epoch 4/6
# 10/10 [==============================] - 5s 533ms/step - loss: 1.4972 - accuracy: 0.6342 - IoU: 0.2953 - val_loss: 1.3154 - val_accuracy: 0.6157 - val_IoU: 0.3013
# Epoch 5/6
# 10/10 [==============================] - 5s 533ms/step - loss: 1.3628 - accuracy: 0.5067 - IoU: 0.2752 - val_loss: 1.2862 - val_accuracy: 0.5279 - val_IoU: 0.3080
# Epoch 6/6
# 10/10 [==============================] - 6s 567ms/step - loss: 1.2498 - accuracy: 0.6485 - IoU: 0.3725 - val_loss: 0.9461 - val_accuracy: 0.7195 - val_IoU: 0.3800
# Validation accuracy: 0.7195242047309875, Validation IoU: 0.38003695011138916
# Configuration 13/15 -> current parameters:  {'n_filters_list': [16, 32, 64, 128], 'batch_size': 8}
# Evaluating...
# Epoch 1/6
# 40/40 [==============================] - 13s 100ms/step - loss: 1.7813 - accuracy: 0.3912 - IoU: 0.1305 - val_loss: 1.6748 - val_accuracy: 0.3102 - val_IoU: 0.1270
# Epoch 2/6
# 40/40 [==============================] - 3s 81ms/step - loss: 1.5989 - accuracy: 0.5850 - IoU: 0.2180 - val_loss: 1.2938 - val_accuracy: 0.6259 - val_IoU: 0.2230
# Epoch 3/6
# 40/40 [==============================] - 3s 83ms/step - loss: 1.4619 - accuracy: 0.4977 - IoU: 0.2319 - val_loss: 1.3966 - val_accuracy: 0.5141 - val_IoU: 0.2625
# Epoch 4/6
# 40/40 [==============================] - 3s 79ms/step - loss: 1.3580 - accuracy: 0.6552 - IoU: 0.3247 - val_loss: 1.1224 - val_accuracy: 0.7141 - val_IoU: 0.3682
# Epoch 5/6
# 40/40 [==============================] - 3s 82ms/step - loss: 1.3493 - accuracy: 0.4839 - IoU: 0.2921 - val_loss: 1.3158 - val_accuracy: 0.5243 - val_IoU: 0.3004
# Epoch 6/6
# 40/40 [==============================] - 3s 84ms/step - loss: 1.2588 - accuracy: 0.6669 - IoU: 0.3673 - val_loss: 1.3879 - val_accuracy: 0.4208 - val_IoU: 0.2573
# Validation accuracy: 0.42077237367630005, Validation IoU: 0.2572723925113678
# Configuration 14/15 -> current parameters:  {'n_filters_list': [16, 32, 64, 128], 'batch_size': 16}
# Evaluating...
# Epoch 1/6
# 20/20 [==============================] - 12s 186ms/step - loss: 1.7522 - accuracy: 0.4619 - IoU: 0.1148 - val_loss: 1.5391 - val_accuracy: 0.5416 - val_IoU: 0.1316
# Epoch 2/6
# 20/20 [==============================] - 3s 152ms/step - loss: 1.6862 - accuracy: 0.5111 - IoU: 0.1268 - val_loss: 1.4117 - val_accuracy: 0.5587 - val_IoU: 0.1481
# Epoch 3/6
# 20/20 [==============================] - 3s 157ms/step - loss: 1.5632 - accuracy: 0.5519 - IoU: 0.1939 - val_loss: 1.3999 - val_accuracy: 0.5879 - val_IoU: 0.2154
# Epoch 4/6
# 20/20 [==============================] - 3s 167ms/step - loss: 1.4356 - accuracy: 0.5877 - IoU: 0.2594 - val_loss: 1.1782 - val_accuracy: 0.6074 - val_IoU: 0.2114
# Epoch 5/6
# 20/20 [==============================] - 3s 153ms/step - loss: 1.3322 - accuracy: 0.6261 - IoU: 0.2860 - val_loss: 1.1054 - val_accuracy: 0.6982 - val_IoU: 0.3430
# Epoch 6/6
# 20/20 [==============================] - 3s 154ms/step - loss: 1.2595 - accuracy: 0.6768 - IoU: 0.3494 - val_loss: 1.2584 - val_accuracy: 0.6431 - val_IoU: 0.3467
# Validation accuracy: 0.64306640625, Validation IoU: 0.34672796726226807
# Configuration 15/15 -> current parameters:  {'n_filters_list': [16, 32, 64, 128], 'batch_size': 32}
# Evaluating...
# Epoch 1/6
# 10/10 [==============================] - 12s 387ms/step - loss: 1.7473 - accuracy: 0.2217 - IoU: 0.0782 - val_loss: 1.6106 - val_accuracy: 0.2151 - val_IoU: 0.0581
# Epoch 2/6
# 10/10 [==============================] - 3s 317ms/step - loss: 1.6739 - accuracy: 0.4148 - IoU: 0.1450 - val_loss: 1.4621 - val_accuracy: 0.4782 - val_IoU: 0.1916
# Epoch 3/6
# 10/10 [==============================] - 3s 324ms/step - loss: 1.5912 - accuracy: 0.5593 - IoU: 0.2224 - val_loss: 1.3089 - val_accuracy: 0.5880 - val_IoU: 0.2196
# Epoch 4/6
# 10/10 [==============================] - 3s 314ms/step - loss: 1.5178 - accuracy: 0.5956 - IoU: 0.2250 - val_loss: 1.1376 - val_accuracy: 0.6021 - val_IoU: 0.2216
# Epoch 5/6
# 10/10 [==============================] - 3s 316ms/step - loss: 1.4888 - accuracy: 0.5546 - IoU: 0.2270 - val_loss: 1.2226 - val_accuracy: 0.5713 - val_IoU: 0.2377
# Epoch 6/6
# 10/10 [==============================] - 3s 324ms/step - loss: 1.4049 - accuracy: 0.5564 - IoU: 0.2383 - val_loss: 1.1693 - val_accuracy: 0.5999 - val_IoU: 0.2691
# Validation accuracy: 0.5999309420585632, Validation IoU: 0.2691230773925781
# Best Score: 0.7368665933609009
# Best Params: {'n_filters_list': [32, 64], 'batch_size': 16}

# %%
clear_session()

# %% [markdown]
# ##Refitting the best model on the full training dataset

# %%
best_model = FCNN(img_shape,
                  n_classes,
                  n_filters_list=best_params['n_filters_list'])

# %%
best_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  conv2d (Conv2D)             (None, 256, 256, 32)         896       ['input_1[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 256, 256, 32)         9248      ['conv2d[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 128, 128, 32)         0         ['conv2d_1[0][0]']
#  D)
#
#  conv2d_2 (Conv2D)           (None, 128, 128, 64)         18496     ['max_pooling2d[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 128, 128, 64)         36928     ['conv2d_2[0][0]']
#
#  max_pooling2d_1 (MaxPoolin  (None, 64, 64, 64)           0         ['conv2d_3[0][0]']
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 64, 64, 64)           36928     ['max_pooling2d_1[0][0]']
#
#  conv2d_5 (Conv2D)           (None, 64, 64, 64)           36928     ['conv2d_4[0][0]']
#
#  conv2d_transpose (Conv2DTr  (None, 128, 128, 64)         16448     ['conv2d_5[0][0]']
#  anspose)
#
#  concatenate (Concatenate)   (None, 128, 128, 128)        0         ['conv2d_3[0][0]',
#                                                                      'conv2d_transpose[0][0]']
#
#  conv2d_6 (Conv2D)           (None, 128, 128, 64)         73792     ['concatenate[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 128, 128, 64)         36928     ['conv2d_6[0][0]']
#
#  conv2d_transpose_1 (Conv2D  (None, 256, 256, 32)         8224      ['conv2d_7[0][0]']
#  Transpose)
#
#  concatenate_1 (Concatenate  (None, 256, 256, 64)         0         ['conv2d_1[0][0]',
#  )                                                                   'conv2d_transpose_1[0][0]']
#
#  conv2d_8 (Conv2D)           (None, 256, 256, 32)         18464     ['concatenate_1[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 256, 256, 32)         9248      ['conv2d_8[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 256, 256, 6)          198       ['conv2d_9[0][0]']
#
# ==================================================================================================
# Total params: 302726 (1.15 MB)
# Trainable params: 302726 (1.15 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss',
                                            patience=12,
                                            mode='min',
                                            restore_best_weights=True)

history = best_model.fit(X_train, y_train, batch_size=best_params['batch_size'], epochs=100, class_weight=class_weights, validation_split=.2, callbacks=[callback])
# Out:
# Epoch 1/100
# 53/53 [==============================] - 34s 316ms/step - loss: 1.6924 - accuracy: 0.4542 - IoU: 0.1577 - val_loss: 1.6978 - val_accuracy: 0.3171 - val_IoU: 0.1883
# Epoch 2/100
# 53/53 [==============================] - 11s 212ms/step - loss: 1.3795 - accuracy: 0.5494 - IoU: 0.3099 - val_loss: 1.4545 - val_accuracy: 0.2673 - val_IoU: 0.2638
# Epoch 3/100
# 53/53 [==============================] - 12s 228ms/step - loss: 1.2315 - accuracy: 0.5921 - IoU: 0.3685 - val_loss: 1.0099 - val_accuracy: 0.7173 - val_IoU: 0.4098
# Epoch 4/100
# 53/53 [==============================] - 11s 217ms/step - loss: 1.2025 - accuracy: 0.6090 - IoU: 0.3908 - val_loss: 0.9955 - val_accuracy: 0.6962 - val_IoU: 0.4432
# Epoch 5/100
# 53/53 [==============================] - 12s 226ms/step - loss: 1.1171 - accuracy: 0.6681 - IoU: 0.4275 - val_loss: 1.0281 - val_accuracy: 0.6992 - val_IoU: 0.4462
# Epoch 6/100
# 53/53 [==============================] - 11s 214ms/step - loss: 1.0587 - accuracy: 0.6755 - IoU: 0.4463 - val_loss: 1.1252 - val_accuracy: 0.5970 - val_IoU: 0.4464
# Epoch 7/100
# 53/53 [==============================] - 12s 223ms/step - loss: 1.0816 - accuracy: 0.6837 - IoU: 0.4490 - val_loss: 0.8730 - val_accuracy: 0.7319 - val_IoU: 0.4896
# Epoch 8/100
# 53/53 [==============================] - 11s 213ms/step - loss: 1.0400 - accuracy: 0.6918 - IoU: 0.4646 - val_loss: 0.7556 - val_accuracy: 0.7890 - val_IoU: 0.5135
# Epoch 9/100
# 53/53 [==============================] - 11s 215ms/step - loss: 1.0069 - accuracy: 0.7021 - IoU: 0.4734 - val_loss: 1.4915 - val_accuracy: 0.3161 - val_IoU: 0.3840
# Epoch 10/100
# 53/53 [==============================] - 12s 218ms/step - loss: 0.9888 - accuracy: 0.6928 - IoU: 0.4797 - val_loss: 0.8978 - val_accuracy: 0.7180 - val_IoU: 0.5096
# Epoch 11/100
# 53/53 [==============================] - 12s 232ms/step - loss: 0.9419 - accuracy: 0.7104 - IoU: 0.4974 - val_loss: 0.9148 - val_accuracy: 0.6826 - val_IoU: 0.4611
# Epoch 12/100
# 53/53 [==============================] - 11s 216ms/step - loss: 0.9092 - accuracy: 0.7172 - IoU: 0.5040 - val_loss: 0.7148 - val_accuracy: 0.7747 - val_IoU: 0.5403
# Epoch 13/100
# 53/53 [==============================] - 11s 216ms/step - loss: 0.8640 - accuracy: 0.7011 - IoU: 0.5062 - val_loss: 0.7858 - val_accuracy: 0.7542 - val_IoU: 0.5165
# Epoch 14/100
# 53/53 [==============================] - 12s 225ms/step - loss: 0.8639 - accuracy: 0.7126 - IoU: 0.5089 - val_loss: 0.8198 - val_accuracy: 0.7050 - val_IoU: 0.5125
# Epoch 15/100
# 53/53 [==============================] - 12s 226ms/step - loss: 0.8694 - accuracy: 0.7109 - IoU: 0.5135 - val_loss: 0.8840 - val_accuracy: 0.6894 - val_IoU: 0.5182
# Epoch 16/100
# 53/53 [==============================] - 11s 215ms/step - loss: 0.8561 - accuracy: 0.7073 - IoU: 0.5124 - val_loss: 0.8247 - val_accuracy: 0.7323 - val_IoU: 0.5209
# Epoch 17/100
# 53/53 [==============================] - 12s 226ms/step - loss: 0.8670 - accuracy: 0.7082 - IoU: 0.5063 - val_loss: 0.8012 - val_accuracy: 0.7386 - val_IoU: 0.5286
# Epoch 18/100
# 53/53 [==============================] - 11s 216ms/step - loss: 0.8448 - accuracy: 0.7330 - IoU: 0.5205 - val_loss: 1.0353 - val_accuracy: 0.5794 - val_IoU: 0.4845
# Epoch 19/100
# 53/53 [==============================] - 12s 224ms/step - loss: 0.8411 - accuracy: 0.6923 - IoU: 0.5121 - val_loss: 0.8237 - val_accuracy: 0.7654 - val_IoU: 0.5291
# Epoch 20/100
# 53/53 [==============================] - 11s 214ms/step - loss: 0.8291 - accuracy: 0.7160 - IoU: 0.5198 - val_loss: 0.7827 - val_accuracy: 0.7417 - val_IoU: 0.5202
# Epoch 21/100
# 53/53 [==============================] - 11s 215ms/step - loss: 0.7975 - accuracy: 0.7160 - IoU: 0.5230 - val_loss: 0.7600 - val_accuracy: 0.7664 - val_IoU: 0.5450
# Epoch 22/100
# 53/53 [==============================] - 12s 225ms/step - loss: 0.8315 - accuracy: 0.7111 - IoU: 0.5142 - val_loss: 0.8698 - val_accuracy: 0.7034 - val_IoU: 0.5289
# Epoch 23/100
# 53/53 [==============================] - 11s 215ms/step - loss: 0.7865 - accuracy: 0.7139 - IoU: 0.5223 - val_loss: 0.7484 - val_accuracy: 0.7355 - val_IoU: 0.5426
# Epoch 24/100
# 53/53 [==============================] - 12s 225ms/step - loss: 0.7889 - accuracy: 0.7174 - IoU: 0.5253 - val_loss: 0.6472 - val_accuracy: 0.7838 - val_IoU: 0.5638
# Epoch 25/100
# 53/53 [==============================] - 12s 225ms/step - loss: 0.7666 - accuracy: 0.7223 - IoU: 0.5289 - val_loss: 0.7368 - val_accuracy: 0.7471 - val_IoU: 0.5383
# Epoch 26/100
# 53/53 [==============================] - 12s 226ms/step - loss: 0.7845 - accuracy: 0.7053 - IoU: 0.5160 - val_loss: 0.7385 - val_accuracy: 0.7706 - val_IoU: 0.5368
# Epoch 27/100
# 53/53 [==============================] - 12s 225ms/step - loss: 0.7515 - accuracy: 0.7317 - IoU: 0.5331 - val_loss: 0.8815 - val_accuracy: 0.6736 - val_IoU: 0.5135
# Epoch 28/100
# 53/53 [==============================] - 11s 216ms/step - loss: 0.7541 - accuracy: 0.7235 - IoU: 0.5286 - val_loss: 0.8307 - val_accuracy: 0.6612 - val_IoU: 0.5220
# Epoch 29/100
# 53/53 [==============================] - 11s 215ms/step - loss: 0.7616 - accuracy: 0.7148 - IoU: 0.5269 - val_loss: 0.6648 - val_accuracy: 0.7815 - val_IoU: 0.5281
# Epoch 30/100
# 53/53 [==============================] - 12s 225ms/step - loss: 0.7314 - accuracy: 0.7311 - IoU: 0.5321 - val_loss: 0.7223 - val_accuracy: 0.7506 - val_IoU: 0.5468
# Epoch 31/100
# 53/53 [==============================] - 12s 226ms/step - loss: 0.7546 - accuracy: 0.7218 - IoU: 0.5281 - val_loss: 0.6832 - val_accuracy: 0.7836 - val_IoU: 0.5562
# Epoch 32/100
# 53/53 [==============================] - 12s 226ms/step - loss: 0.7207 - accuracy: 0.7295 - IoU: 0.5332 - val_loss: 0.6215 - val_accuracy: 0.7815 - val_IoU: 0.5508
# Epoch 33/100
# 53/53 [==============================] - 11s 216ms/step - loss: 0.7414 - accuracy: 0.7222 - IoU: 0.5272 - val_loss: 0.6728 - val_accuracy: 0.7662 - val_IoU: 0.5602
# Epoch 34/100
# 53/53 [==============================] - 12s 226ms/step - loss: 0.7147 - accuracy: 0.7273 - IoU: 0.5360 - val_loss: 0.6050 - val_accuracy: 0.7968 - val_IoU: 0.5637
# Epoch 35/100
# 53/53 [==============================] - 12s 224ms/step - loss: 0.6970 - accuracy: 0.7293 - IoU: 0.5306 - val_loss: 0.6387 - val_accuracy: 0.7862 - val_IoU: 0.5586
# Epoch 36/100
# 53/53 [==============================] - 11s 214ms/step - loss: 0.7039 - accuracy: 0.7255 - IoU: 0.5334 - val_loss: 0.7232 - val_accuracy: 0.7590 - val_IoU: 0.5541
# Epoch 37/100
# 53/53 [==============================] - 12s 222ms/step - loss: 0.6979 - accuracy: 0.7336 - IoU: 0.5401 - val_loss: 0.7409 - val_accuracy: 0.7576 - val_IoU: 0.5561
# Epoch 38/100
# 53/53 [==============================] - 12s 223ms/step - loss: 0.6650 - accuracy: 0.7455 - IoU: 0.5422 - val_loss: 0.7832 - val_accuracy: 0.7186 - val_IoU: 0.5458
# Epoch 39/100
# 53/53 [==============================] - 12s 224ms/step - loss: 0.6403 - accuracy: 0.7354 - IoU: 0.5410 - val_loss: 0.6624 - val_accuracy: 0.7603 - val_IoU: 0.5543
# Epoch 40/100
# 53/53 [==============================] - 11s 215ms/step - loss: 0.6515 - accuracy: 0.7336 - IoU: 0.5416 - val_loss: 0.6203 - val_accuracy: 0.7883 - val_IoU: 0.5645
# Epoch 41/100
# 53/53 [==============================] - 12s 226ms/step - loss: 0.6564 - accuracy: 0.7382 - IoU: 0.5389 - val_loss: 0.8197 - val_accuracy: 0.7171 - val_IoU: 0.5487
# Epoch 42/100
# 53/53 [==============================] - 12s 225ms/step - loss: 0.6148 - accuracy: 0.7473 - IoU: 0.5484 - val_loss: 0.8250 - val_accuracy: 0.7021 - val_IoU: 0.5285
# Epoch 43/100
# 53/53 [==============================] - 12s 225ms/step - loss: 0.6757 - accuracy: 0.7248 - IoU: 0.5257 - val_loss: 0.6705 - val_accuracy: 0.7769 - val_IoU: 0.5619
# Epoch 44/100
# 53/53 [==============================] - 11s 216ms/step - loss: 0.6352 - accuracy: 0.7517 - IoU: 0.5483 - val_loss: 0.7261 - val_accuracy: 0.7437 - val_IoU: 0.5400
# Epoch 45/100
# 53/53 [==============================] - 11s 215ms/step - loss: 0.6280 - accuracy: 0.7279 - IoU: 0.5344 - val_loss: 0.5803 - val_accuracy: 0.8012 - val_IoU: 0.5655
# Epoch 46/100
# 53/53 [==============================] - 11s 215ms/step - loss: 0.6362 - accuracy: 0.7494 - IoU: 0.5453 - val_loss: 0.9343 - val_accuracy: 0.6831 - val_IoU: 0.5291
# Epoch 47/100
# 53/53 [==============================] - 12s 225ms/step - loss: 0.6260 - accuracy: 0.7237 - IoU: 0.5373 - val_loss: 0.6572 - val_accuracy: 0.7862 - val_IoU: 0.5584
# Epoch 48/100
# 53/53 [==============================] - 11s 215ms/step - loss: 0.6379 - accuracy: 0.7427 - IoU: 0.5411 - val_loss: 0.6122 - val_accuracy: 0.7974 - val_IoU: 0.5643
# Epoch 49/100
# 53/53 [==============================] - 12s 226ms/step - loss: 0.6096 - accuracy: 0.7494 - IoU: 0.5479 - val_loss: 0.5671 - val_accuracy: 0.8063 - val_IoU: 0.5698
# Epoch 50/100
# 53/53 [==============================] - 11s 216ms/step - loss: 0.5879 - accuracy: 0.7569 - IoU: 0.5523 - val_loss: 0.6737 - val_accuracy: 0.7641 - val_IoU: 0.5655
# Epoch 51/100
# 53/53 [==============================] - 11s 216ms/step - loss: 0.5427 - accuracy: 0.7629 - IoU: 0.5578 - val_loss: 0.6056 - val_accuracy: 0.7879 - val_IoU: 0.5701
# Epoch 52/100
# 53/53 [==============================] - 11s 214ms/step - loss: 0.5754 - accuracy: 0.7610 - IoU: 0.5507 - val_loss: 0.6704 - val_accuracy: 0.7730 - val_IoU: 0.5469
# Epoch 53/100
# 53/53 [==============================] - 12s 223ms/step - loss: 0.5869 - accuracy: 0.7551 - IoU: 0.5510 - val_loss: 0.5687 - val_accuracy: 0.8031 - val_IoU: 0.5745
# Epoch 54/100
# 53/53 [==============================] - 11s 215ms/step - loss: 0.5594 - accuracy: 0.7561 - IoU: 0.5520 - val_loss: 0.5856 - val_accuracy: 0.7990 - val_IoU: 0.5759
# Epoch 55/100
# 53/53 [==============================] - 11s 216ms/step - loss: 0.5492 - accuracy: 0.7610 - IoU: 0.5558 - val_loss: 0.5832 - val_accuracy: 0.8017 - val_IoU: 0.5775
# Epoch 56/100
# 53/53 [==============================] - 11s 216ms/step - loss: 0.5282 - accuracy: 0.7682 - IoU: 0.5584 - val_loss: 0.6182 - val_accuracy: 0.7830 - val_IoU: 0.5625
# Epoch 57/100
# 53/53 [==============================] - 11s 215ms/step - loss: 0.5637 - accuracy: 0.7589 - IoU: 0.5503 - val_loss: 0.6599 - val_accuracy: 0.7591 - val_IoU: 0.5519
# Epoch 58/100
# 53/53 [==============================] - 11s 216ms/step - loss: 0.5433 - accuracy: 0.7616 - IoU: 0.5508 - val_loss: 0.7428 - val_accuracy: 0.7273 - val_IoU: 0.5395
# Epoch 59/100
# 53/53 [==============================] - 11s 215ms/step - loss: 0.5643 - accuracy: 0.7547 - IoU: 0.5482 - val_loss: 0.6610 - val_accuracy: 0.7622 - val_IoU: 0.5392
# Epoch 60/100
# 53/53 [==============================] - 12s 225ms/step - loss: 0.5409 - accuracy: 0.7676 - IoU: 0.5611 - val_loss: 0.6138 - val_accuracy: 0.7909 - val_IoU: 0.5695
# Epoch 61/100
# 53/53 [==============================] - 11s 216ms/step - loss: 0.5086 - accuracy: 0.7714 - IoU: 0.5615 - val_loss: 0.5519 - val_accuracy: 0.8128 - val_IoU: 0.5761
# Epoch 62/100
# 53/53 [==============================] - 11s 215ms/step - loss: 0.4917 - accuracy: 0.7777 - IoU: 0.5645 - val_loss: 0.8079 - val_accuracy: 0.6900 - val_IoU: 0.5244
# Epoch 63/100
# 53/53 [==============================] - 11s 216ms/step - loss: 0.5178 - accuracy: 0.7679 - IoU: 0.5580 - val_loss: 0.6249 - val_accuracy: 0.7876 - val_IoU: 0.5644
# Epoch 64/100
# 53/53 [==============================] - 11s 214ms/step - loss: 0.4908 - accuracy: 0.7736 - IoU: 0.5629 - val_loss: 0.6533 - val_accuracy: 0.7718 - val_IoU: 0.5545
# Epoch 65/100
# 53/53 [==============================] - 12s 225ms/step - loss: 0.4860 - accuracy: 0.7730 - IoU: 0.5641 - val_loss: 0.6128 - val_accuracy: 0.7962 - val_IoU: 0.5629
# Epoch 66/100
# 53/53 [==============================] - 11s 215ms/step - loss: 0.5047 - accuracy: 0.7776 - IoU: 0.5644 - val_loss: 0.6435 - val_accuracy: 0.7784 - val_IoU: 0.5589
# Epoch 67/100
# 53/53 [==============================] - 12s 226ms/step - loss: 0.5800 - accuracy: 0.7608 - IoU: 0.5533 - val_loss: 0.5939 - val_accuracy: 0.8043 - val_IoU: 0.5788
# Epoch 68/100
# 53/53 [==============================] - 12s 226ms/step - loss: 0.5291 - accuracy: 0.7725 - IoU: 0.5589 - val_loss: 0.8391 - val_accuracy: 0.6806 - val_IoU: 0.5197
# Epoch 69/100
# 53/53 [==============================] - 11s 216ms/step - loss: 0.6652 - accuracy: 0.6754 - IoU: 0.5016 - val_loss: 0.6489 - val_accuracy: 0.7888 - val_IoU: 0.5586
# Epoch 70/100
# 53/53 [==============================] - 11s 216ms/step - loss: 0.5311 - accuracy: 0.7762 - IoU: 0.5645 - val_loss: 0.6249 - val_accuracy: 0.7852 - val_IoU: 0.5686
# Epoch 71/100
# 53/53 [==============================] - 12s 227ms/step - loss: 0.5159 - accuracy: 0.7675 - IoU: 0.5576 - val_loss: 0.5188 - val_accuracy: 0.8151 - val_IoU: 0.5809
# Epoch 72/100
# 53/53 [==============================] - 11s 216ms/step - loss: 0.5188 - accuracy: 0.7725 - IoU: 0.5593 - val_loss: 0.5533 - val_accuracy: 0.8092 - val_IoU: 0.5740
# Epoch 73/100
# 53/53 [==============================] - 11s 216ms/step - loss: 0.4731 - accuracy: 0.7862 - IoU: 0.5700 - val_loss: 0.5760 - val_accuracy: 0.8045 - val_IoU: 0.5768
# Epoch 74/100
# 53/53 [==============================] - 12s 226ms/step - loss: 0.4582 - accuracy: 0.7888 - IoU: 0.5730 - val_loss: 0.5666 - val_accuracy: 0.8087 - val_IoU: 0.5668
# Epoch 75/100
# 53/53 [==============================] - 12s 224ms/step - loss: 0.4585 - accuracy: 0.7938 - IoU: 0.5774 - val_loss: 0.6712 - val_accuracy: 0.7823 - val_IoU: 0.5682
# Epoch 76/100
# 53/53 [==============================] - 11s 216ms/step - loss: 0.4532 - accuracy: 0.7948 - IoU: 0.5792 - val_loss: 0.6797 - val_accuracy: 0.7627 - val_IoU: 0.5545
# Epoch 77/100
# 53/53 [==============================] - 12s 226ms/step - loss: 0.4454 - accuracy: 0.7924 - IoU: 0.5777 - val_loss: 0.5109 - val_accuracy: 0.8234 - val_IoU: 0.5796
# Epoch 78/100
# 53/53 [==============================] - 11s 216ms/step - loss: 0.4625 - accuracy: 0.7953 - IoU: 0.5757 - val_loss: 0.7178 - val_accuracy: 0.7555 - val_IoU: 0.5404
# Epoch 79/100
# 53/53 [==============================] - 11s 214ms/step - loss: 0.6269 - accuracy: 0.7515 - IoU: 0.5414 - val_loss: 0.6560 - val_accuracy: 0.7913 - val_IoU: 0.5663
# Epoch 80/100
# 53/53 [==============================] - 11s 214ms/step - loss: 0.4807 - accuracy: 0.7830 - IoU: 0.5652 - val_loss: 0.6049 - val_accuracy: 0.7831 - val_IoU: 0.5620
# Epoch 81/100
# 53/53 [==============================] - 11s 216ms/step - loss: 0.4417 - accuracy: 0.7953 - IoU: 0.5795 - val_loss: 0.5645 - val_accuracy: 0.8029 - val_IoU: 0.5610
# Epoch 82/100
# 53/53 [==============================] - 11s 215ms/step - loss: 0.4279 - accuracy: 0.7974 - IoU: 0.5808 - val_loss: 0.6075 - val_accuracy: 0.7879 - val_IoU: 0.5646
# Epoch 83/100
# 53/53 [==============================] - 12s 225ms/step - loss: 0.4200 - accuracy: 0.8020 - IoU: 0.5867 - val_loss: 0.5611 - val_accuracy: 0.8152 - val_IoU: 0.5734
# Epoch 84/100
# 53/53 [==============================] - 11s 216ms/step - loss: 0.4331 - accuracy: 0.8004 - IoU: 0.5839 - val_loss: 0.5206 - val_accuracy: 0.8213 - val_IoU: 0.5822
# Epoch 85/100
# 53/53 [==============================] - 12s 226ms/step - loss: 0.4404 - accuracy: 0.7942 - IoU: 0.5777 - val_loss: 0.5369 - val_accuracy: 0.8096 - val_IoU: 0.5747
# Epoch 86/100
# 53/53 [==============================] - 11s 217ms/step - loss: 0.4318 - accuracy: 0.7956 - IoU: 0.5810 - val_loss: 0.5747 - val_accuracy: 0.8148 - val_IoU: 0.5807
# Epoch 87/100
# 53/53 [==============================] - 12s 225ms/step - loss: 0.4221 - accuracy: 0.8075 - IoU: 0.5903 - val_loss: 0.6225 - val_accuracy: 0.7869 - val_IoU: 0.5571
# Epoch 88/100
# 53/53 [==============================] - 12s 225ms/step - loss: 0.4148 - accuracy: 0.8063 - IoU: 0.5910 - val_loss: 0.5716 - val_accuracy: 0.8139 - val_IoU: 0.5745
# Epoch 89/100
# 53/53 [==============================] - 12s 226ms/step - loss: 0.4080 - accuracy: 0.8067 - IoU: 0.5914 - val_loss: 0.6296 - val_accuracy: 0.7740 - val_IoU: 0.5471

# %%
y_hat = best_model.predict(X_test)
y_pred = tf.expand_dims(tf.argmax(y_hat, axis=-1), axis=-1)
# Out:
# 9/9 [==============================] - 7s 251ms/step

# %%
accuracy_score(y_test.reshape(-1), y_pred.numpy().reshape(-1))
# Out:
# 0.8073180333864644

# %%
m_iou = MeanIoU(num_classes=n_classes)
m_iou.update_state(y_test, y_pred)
m_iou.result().numpy()
# Out:
# 0.56454194

# %%
visualize_predictions(X_test, y_test, y_pred, random.randint(0,len(y_test)-1))

# %% [markdown]
# ##Model evaluation

# %%
plot_learning_curve(history)

# %%
plot_confusion_matrix(y_test, y_pred, n_classes)
